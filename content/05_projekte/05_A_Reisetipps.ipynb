# %% [markdown]
# # Reise Tipps
#
# ### Spielanleitung:
#
# ---
#
# ### **Reise-Tipps-Spiel**
#
# Willkommen im Reise-Tipps-Spiel! 🎉
#
# In diesem Spiel kannst du eine Stadt eingeben und bekommst einen hilfreichen Tipp zu einer Sehenswürdigkeit, die du in dieser Stadt besuchen kannst.
#
# ### **So funktioniert's:**
#
# 1. **Gib eine Stadt ein:** Du wirst aufgefordert, eine Stadt einzugeben, zum Beispiel "Berlin", "Paris" oder "Rom".
#
# 2. **Tipp bekommen:** Das Programm wird dir dann einen besonderen Tipp für diese Stadt geben! Du erfährst, welche Sehenswürdigkeit du in dieser Stadt unbedingt besuchen solltest.
#
# 3. **Unbekannte Städte:** Wenn du eine Stadt eingibst, die nicht im Spiel enthalten ist, bekommst du die Nachricht: "Erkunde die Sehenswürdigkeiten vor Ort!" und kannst weiterhin die Stadt genießen.
#
# ---
#
# ### **Tipps:**
#
# * Achte darauf, den Städtenamen richtig zu schreiben (aber keine Sorge, das Programm macht die Eingabe automatisch klein, sodass es nicht auf Groß- oder Kleinschreibung ankommt).
#
# * Du kannst das Spiel beliebig oft spielen und verschiedene Städte ausprobieren, um neue Tipps zu bekommen.
#
# * Wenn du eine Stadt nicht im Spiel findest, keine Sorge! Du kannst sie trotzdem besuchen und neue Sehenswürdigkeiten entdecken.
#
# ---
#
# ### Beispiel:
#
# **Frage:**
# In welcher Stadt bist du?
#
# **Antwort:**
# "Berlin"
#
# **Ergebnis:**
# "Besuche das Brandenburger Tor!"
#
#
# ---
#
# Viel Spaß beim Reisen und Entdecken der schönsten Sehenswürdigkeiten weltweit! 🌍✨

# %% [markdown]
# ---
#
# ### **Tipps für den Code-Aufbau:**
#
# #### 1. **Überlege dir, was du brauchst:**
#
# * Zuerst musst du wissen, was das Programm machen soll: Du möchtest eine Funktion, die basierend auf einer Stadt einen Tipp zu einer Sehenswürdigkeit ausgibt.
# * Das heißt: Du brauchst eine Datenstruktur, um Städte und Sehenswürdigkeiten zu speichern, eine Funktion, die die Eingabe des Nutzers verarbeitet, und eine Möglichkeit, die Antwort zu liefern.
#
# #### 2. **Welche Datenstruktur verwenden?**
#
# * Du solltest ein **Dictionary** verwenden. Ein Dictionary speichert Werte (die Sehenswürdigkeiten) unter einem Schlüssel (der Stadt).
#
#   * Beispiel: `"berlin": "Besuche das Brandenburger Tor!"`
# * Dies macht es leicht, nach der Stadt zu suchen und den entsprechenden Tipp auszugeben.
#
# #### 3. **Wie prüft man, ob eine Stadt im Dictionary ist?**
#
# * Du solltest mit einem **`if`-Statement** prüfen, ob der eingegebene Wert (die Stadt) im Dictionary vorhanden ist.
# * **Tipp:** Da der Benutzer die Stadt möglicherweise mit Großbuchstaben eingibt, kannst du den eingegebenen Text mit `.lower()` zu Kleinbuchstaben umwandeln. Dadurch wird die Groß-/Kleinschreibung ignoriert.
#
# #### 4. **Fehlerbehandlung:**
#
# * Wenn die Stadt nicht im Dictionary vorhanden ist, kannst du eine Standardnachricht anzeigen, wie „Erkunde die Sehenswürdigkeiten vor Ort!“.
# * Dies kann mit einem **`else`-Zweig** im `if`-Statement erreicht werden.
#
# #### 5. **Die Funktion und das Hauptprogramm:**
#
# * Deine Funktion **`reise_tipps(stadt)`** bekommt die Stadt als Eingabe und sucht nach dem entsprechenden Tipp im Dictionary.
# * Danach gibt sie den Tipp oder eine Standardnachricht aus.
# * Im Hauptprogramm fragst du den Benutzer nach einer Stadt und rufst dann die Funktion mit der Eingabe des Benutzers auf.
#
# ---
#
# ### **Code-Aufbau Schritt für Schritt:**
#
# 1. **Definiere die Funktion `reise_tipps(stadt)`:**
#
#    * Die Funktion soll das Dictionary mit den Städten und Tipps enthalten.
#    * Überprüfe, ob die Stadt im Dictionary ist und gib den entsprechenden Tipp aus.
#
#
# 2. **Erstelle das Hauptprogramm:**
#
#    * Hier wird der Benutzer nach einer Stadt gefragt.
#    * Danach rufst du die Funktion `reise_tipps()` mit der eingegebenen Stadt auf.
#
#
# ---
#
# ### **Weitere Tipps zum Code-Design:**
#
# * **Benutzerfreundlichkeit:** Wenn du möchtest, dass das Spiel benutzerfreundlicher ist, kannst du die Eingabe des Benutzers mit `.capitalize()` formatieren, um die erste Buchstabe der Stadt groß zu schreiben. Das sorgt dafür, dass der Benutzer die Stadt mit einer korrekten Schreibweise sieht.
#
# * **Testen und anpassen:** Probiere verschiedene Städte aus, die nicht im Dictionary sind, um sicherzustellen, dass die Standardantwort richtig funktioniert.
#
# * **Verwendung von `.lower()`:** Das hilft sicherzustellen, dass der Benutzer nicht darauf achten muss, ob er "Berlin", "berlin" oder "BERLIN" eingibt. Es wird alles zu Kleinbuchstaben umgewandelt und dann verglichen.
#
# ---
#
# ### **Zusammenfassung der Schritte, um den Code selbst zu erstellen:**
#
# 1. Überlege dir, dass du Städte und Sehenswürdigkeiten speichern musst – daher ein Dictionary.
# 2. Erstelle eine Funktion, die einen Tipp für die eingegebene Stadt gibt.
# 3. Prüfe mit einer **`if`-Bedingung**, ob die Stadt im Dictionary vorhanden ist.
# 4. Benutze `.lower()`, um die Eingabe des Benutzers unabhängig von der Groß- und Kleinschreibung zu verarbeiten.
# 5. Gib die entsprechende Nachricht aus, wenn die Stadt nicht gefunden wird.
# 6. Frag im Hauptprogramm nach der Stadt und rufe die Funktion auf.
#
# ---
#
# Mit diesen Tipps solltest du in der Lage sein, das Reise-Tipps-Spiel selbst zu erstellen! Viel Erfolg! 😊

# %%
# Dein Code hier
