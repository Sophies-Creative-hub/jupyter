# %% [markdown]
# # 📜 Die Schriftrolle der Verlorenen Wege

# %% [markdown]
# ## 🧙‍♂️ Szene 1: Der Flüsterhain

# %%
print("""
🌳 𝗦𝗖𝗛𝗘𝗡𝗘 𝟭: Der Flüsterhain
━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
Du stehst in einem Kreis aus zehn alten Bäumen. Der Wind flüstert:
  „Unter einem von ihnen liegt ein geheimer Schatz... wähle weise.“

""")

print("""
            🌲   🌲   🌲
         🌲   🌲   🌲   🌲
            🌲   🌲   🌲
""")

baum = input("Welchen Baum willst du untersuchen? (1–10): ")
baum_nr = # TODO: in ganze Zahl umwandeln

if baum_nr == 6:
    gegenstand1 = "Amulett des Lichts"
    gegenstand2 = "Ring des Echos"
    ausgabe = # TODO: formatiere einen Satz wie: "Du findest: Amulett des Lichts und Ring des Echos!"
    print(ausgabe)
    gefundene_anzahl = 2
else:
    print("Nur Wurzeln und altes Moos... kein Schatz.")
    gefundene_anzahl = 0
# Out:
#   File "<ipython-input-1-b274e0cf34a1>", line 16
#     baum_nr = # TODO: in ganze Zahl umwandeln
#               ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## 🧩 Rätsel 1: Das Nebelrätsel

# %%
print("""
🧩 RÄTSEL DES NEBELS
━━━━━━━━━━━━━━━━━━━━━
Ein rätselhafter Vers erscheint im Nebel:

„Je mehr du nimmst, desto mehr bleibt zurück.
Was bin ich?“

""")
input("Deine Antwort (frei wählbar): ")
print("Der Nebel lacht leise und verschwindet...")

# %% [markdown]
# ## ⚖️ Szene 2: Die Schale der Balance

# %%
print("""
⚖️ 𝗦𝗖𝗛𝗘𝗡𝗘 𝟮: Die Schale der Balance
━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
Vor dir schwebt eine silberne Waage.

Ein Zeichen leuchtet auf:
  „Lege zwei Gewichte, sodass ihre Summe 42 ergibt.“
""")

gewicht1 = int(input("Erstes Gewicht: "))
gewicht2 = # TODO: Ergänze so, dass summe = 42

summe = gewicht1 + gewicht2
print("Gesamtes Gewicht:", summe)

if summe == 42:
    print("✅ Die Waage leuchtet auf – du darfst passieren.")
else:
    print("❌ Die Waage bleibt stumm.")

# %% [markdown]
# ## 🧩 Rätsel 2: Die Stufen des Liedes

# %%
print("""
🧩 RÄTSEL DER LIEDSTUFEN
━━━━━━━━━━━━━━━━━━━━━━━━━
Eine Stimme singt:

„Ich bin hoch, wenn ich jung bin,
und klein, wenn ich alt bin.
Was bin ich?“

""")
input("Dein Tipp: ")
print("Ein Ton klingt auf... die Treppe öffnet sich.")

# %% [markdown]
# ## 🪨 Szene 3: Der Stein der Worte

# %%
print("""
🪨 𝗦𝗖𝗛𝗘𝗡𝗘 𝟯: Der Stein der Worte
━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
Ein Runenstein zeigt:
  „Sprich den alten Satz, um weiterzugehen.“

""")

teil1 = "Sprich, Freund,"
teil2 = input("Gib das zweite Fragment ein (z.B. 'Wanderer'): ")
ganzer_satz = # TODO: Kombiniere beide Teile + „ und tritt ein.“

print("📜 Der Satz lautet:")
print(ganzer_satz)

if ganzer_satz == "Sprich, Freund, Wanderer und tritt ein.":
    print("✅ Der Stein öffnet sich – ein Tunnel erscheint.")
else:
    print("❌ Die Runen verlöschen.")

# %% [markdown]
# ## 🧩 Rätsel 3: Die Spiegel-Frage

# %%
print("""
🧩 RÄTSEL DES SPIEGELS
━━━━━━━━━━━━━━━━━━━━━━
„Ich spreche ohne Mund und höre ohne Ohren.
Ich habe keinen Körper, doch der Wind erweckt mich...“

Was bin ich?

""")
input("Deine Antwort: ")
print("Dein Spiegelbild nickt... weiter geht’s.")

# %% [markdown]
# ## 🌉 Szene 4: Die Brücke der Bruchteile

# %%
print("""
🌉 𝗦𝗖𝗛𝗘𝗡𝗘 𝟰: Die Brücke der Bruchteile
━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
Ein schwebender Steg flüstert:
  „Nur wer 75% seines Gewichts vorn trägt, kann sicher überqueren.“

""")

vordergewicht = float(input("Vordergewicht: "))
hintergewicht = float(input("Hintergewicht: "))

verhältnis = # TODO: vordergewicht / (vordergewicht + hintergewicht)

print("Verhältnis berechnet:", verhältnis)

if verhältnis == 0.75:
    print("✅ Die Brücke bleibt stabil – du kommst rüber.")
else:
    print("❌ Die Brücke vibriert gefährlich...")

# %% [markdown]
# # 📚 Szene 5: Das Flüsterarchiv

# %%
print("""
📚 𝗦𝗖𝗛𝗘𝗡𝗘 𝟱: Das Flüsterarchiv
━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
Die Schriftrollen fliegen durch die Luft.

Eine Stimme ruft:
  „Erinnere dich... und forme den Satz der Erleuchtung.“

""")

anzahl = input("Wie viele magische Gegenstände hast du gefunden? ")
gewicht = input("Was war dein Gesamtgewicht? ")
wort = input("Was war dein gesprochenes Fragment (Szene 3)? ")
bruecke = input("Welches Verhältnis hattest du auf der Brücke? ")

finale = # TODO: formatiere "Du fandest X Gegenstände, balanciert Y, sprachst 'Z' und gingst bei R."

print("📜 Dein Satz:")
print(finale)

if "fandest 2 Gegenstände" in finale and "balanciert 42" in finale:
    print("✅ Das Archiv flüstert dir ein geheimes Wort zu...")
else:
    print("❌ Die Worte entschlüpfen dir.")

# %% [markdown]
# ## 🧪 Szene 6: Die Quelle der Träume

# %%
print("""
💧 𝗦𝗖𝗛𝗘𝗡𝗘 𝟲: Die Quelle der Träume
━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
In einer verborgenen Grotte glitzert Wasser, das in Farben schillert.
Ein Schild neben der Quelle sagt:

  „Nur wer sein Inneres mit Worten gießt, darf kosten.“

""")

wort1 = input("Schreibe dein erstes Wunschwort: ")
wort2 = input("Schreibe dein zweites Wunschwort: ")
zauberformel = # TODO: Kombiniere wort1 und wort2 mit " + " und hänge " = Magie" an

print("🌈 Die Quelle murmelt:", zauberformel)

if zauberformel == "Frieden + Hoffnung = Magie":
    print("✅ Die Quelle schenkt dir neue Kraft.")
else:
    print("❌ Die Wasseroberfläche bleibt stumm.")

# %% [markdown]
# ## 🔍 Rätsel 4: Die Schattenfrage

# %%
print("""
🧩 RÄTSEL DER SCHATTEN
━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
„Ich habe Städte, aber keine Häuser.
Ich habe Berge, aber keine Bäume.
Ich habe Wasser, aber keinen Fisch.
Was bin ich?“
""")
input("🧠 Deine Antwort: ")
print("Ein Schatten huscht über den Boden... und verschwindet.")

# %% [markdown]
# # 🔮 Szene 7: Der Kristallaltar

# %%
print("""
🔮 𝗦𝗖𝗛𝗘𝗡𝗘 𝟳: Der Kristallaltar
━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
Ein leuchtender Kristall ruft:
  „Drei Zahlen musst du geben... und eine daraus formen.“

""")

z1 = int(input("Erste Zahl (z. B. 3): "))
z2 = float(input("Zweite Zahl (z. B. 4.5): "))
z3 = input("Dritte Zahl als String (z. B. '7'): ")

# TODO: Multipliziere z1 mit z2 und addiere float(z3)
kristallwert = # TODO

print("💠 Dein Kristallwert ist:", kristallwert)

if kristallwert == 20.5:
    print("✅ Der Kristall beginnt zu schweben...")
else:
    print("❌ Die Farben verblassen.")

# %% [markdown]
# ## 🌬 Szene 8: Die Halle des Windes

# %%
print("""
🌬 𝗦𝗖𝗛𝗘𝗡𝗘 𝟴: Die Halle des Windes
━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
Der Wind formt Buchstaben in der Luft...

  „Addiere den Klang des Windes,
   formatiere ihn zu einem Gedicht der Lüfte.“

""")

zahl1 = input("Erste Komponente (String-Zahl): ")
zahl2 = int(input("Zweite Komponente (ganzzahlig): "))
zahl3 = float(input("Dritte Komponente (Fließkomma): "))

# TODO: Addiere alle Zahlen und formatiere zu: "Der Wind sprach: X"
summe = float(zahl1) + zahl2 + zahl3
gedicht = # TODO

print(gedicht)

if gedicht == "Der Wind sprach: 18.5":
    print("✅ Eine Tür aus Luft öffnet sich lautlos...")
else:
    print("❌ Der Wind verweht deine Worte.")

# %% [markdown]
# ## 🧩 Rätsel 5: Die Augen des Drachen

# %%
print("""
🧩 RÄTSEL DER DRACHEN
━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
„Ich kann nicht gesehen werden, kann aber alles sehen.
Ich kann nicht gehört werden, aber alles hören.
Was bin ich?“
""")
input("🔍 Deine Idee: ")
print("Zwei goldene Augen leuchten auf... und blinzeln langsam.")

# %% [markdown]
# ## 🪙 Szene 9: Der Raum der Spiegelzahlen

# %%
print("""
🪞 𝗦𝗖𝗛𝗘𝗡𝗘 𝟵: Der Raum der Spiegelzahlen
━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
Zwei große Spiegel reflektieren Zahlen.

Eine Inschrift sagt:
  „Finde die Zahl, die sich selbst verdoppelt und dann spiegelt.“

""")

eingabe = int(input("🔢 Gib deine Startzahl ein: "))

# TODO: Berechne: (zahl * 2) + int(str(zahl)[::-1])
spiegelwert = # TODO

print("🪞 Ergebnis der Spiegelung:", spiegelwert)

if spiegelwert == 73:
    print("✅ Die Spiegel zerbrechen zu Staub – du gehst weiter.")
else:
    print("❌ Du siehst nur dein altes Selbst.")

# %% [markdown]
# ## 🧙‍♀️ Szene 10: Der Kreis der Elemente

# %%
print("""
🔥💧🌬🌍 𝗦𝗖𝗛𝗘𝗡𝗘 𝟭𝟬: Der Kreis der Elemente
━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
In einem Kreis stehen vier Runensteine.

Ein Schamanenstab erscheint mit den Worten:
  „Wähle ein Element. Gib ihm Gewicht. Füge seine Zahl zu einem Satz.“

""")

element = input("Wähle ein Element (Feuer, Wasser, Wind, Erde): ")
kraft = int(input("Wie stark soll es sein (1–10)?: "))

satz = # TODO: formatiere z. B. „Du wählst Feuer mit Kraft 8!“

print("🌟", satz)

if satz == "Du wählst Feuer mit Kraft 8!":
    print("✅ Alle Runen leuchten auf – der Kreis akzeptiert dich.")
else:
    print("❌ Nichts passiert... war es das falsche Element?")

# %% [markdown]
# ## 🎉 Finale 🎉

# %%
print("""
╔══════════════════════════════════════════════╗
║  🎉 HERZLICHEN GLÜCKWUNSCH, ABENTEURER! 🎉   ║
╚══════════════════════════════════════════════╝

      ▄▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▄
     █░░░░▒▒▒▒▒▒▒▒▒▒░░░░█
    █░░░▒▒ Du hast ▒▒░░░█
    █░░ alle Prüfungen ░█
    █░  der 10 Szenen  ░█
    █░ mit Magie und   ░█
    █░   Logik gemeistert! ░█
     █░░░░░░░░░░░░░░░░░█
      ▀▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▀

🔓 Das Tor der Erkenntnis steht dir nun offen!
""")
