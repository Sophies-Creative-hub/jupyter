# %% [markdown]
# # Black Jack Anleitung
#
# #### Schwierigkeitsgrade
#
# - **Schwierigkeitsgrad Normal 😎**: Verwende alle unten aufgeführten Hinweise, um das Projekt abzuschließen.
#
# - **Schwierigkeitsgrad Schwer 🤔**: Nutze nur die Hinweise 1, 2 und 3.
#
# - **Schwierigkeitsgrad Sehr Schwer 😭**: Nur Hinweise 1 und 2 verwenden.
#
# - **Schwierigkeitsgrad Experte 🤯**: Nur Hinweis 1 verwenden.

# %% [markdown]
# ---
#
# ## Hinweise:

# %% [markdown]
# 1. **Hinweis 1**: Besuche die folgenden Websites, um ein Gefühl für das Blackjack-Spiel zu bekommen:
#
#   - [Blackjack-Spiel ausprobieren](https://sophies-creative-hub.github.io/Blackjack/)
#
#
#
# 2. **Hinweis 2**: Lies die Anforderungen für das Programm:
#
#   - weiter unten
#
#   - Versuche, einen eigenen Flussdiagramm für das Programm zu erstellen.
#
# 3. **Hinweis 3**: Lade das erstellte Flussdiagramm herunter und lies es
#
# 4. **Hinweis 4**: Erstelle eine `deal_card()`-Funktion, die zufällig eine Karte aus der folgenden Liste zurückgibt:
#
#   ```python
#   cards = [11, 2, 3, 4, 5, 6, 7, 8, 9, 10, 10, 10, 10]
#   ```
#
# **Erklärung der Blackjack-Kartenliste**
#
# Die Liste cards = [11, 2, 3, 4, 5, 6, 7, 8, 9, 10, 10, 10, 10] repräsentiert alle Kartenwerte im Blackjack-Spiel. Die Zahlen in dieser Liste entsprechen den Werten der Spielkarten in einem Standardkartenspiel:
#
# Die Zahlen 2-10 repräsentieren die Karten mit den entsprechenden Zahlenwerten (2 bis 10)
# Die vier "10"-Werte stehen für die Bildkarten: Bube (J), Dame (Q), König (K) und die 10 selbst
# Die "11" repräsentiert das Ass, das im Blackjack entweder als 1 oder 11 gezählt werden kann
#
# In der `deal_card()`-Funktion würde zufällig ein Wert aus dieser Liste ausgewählt werden, um eine Karte zu ziehen. Dies simuliert das Ziehen einer zufälligen Karte aus dem Deck.
# Diese vereinfachte Darstellung ignoriert die verschiedenen Farben (Herz, Pik, Kreuz, Karo) und konzentriert sich nur auf die Werte der Karten, da im Blackjack nur die Zahlenwerte und nicht die Farben relevant sind.
# Das Ass (11) ist besonders wichtig im Blackjack, da es flexibel ist: Es kann als 11 gezählt werden, solange die Gesamtsumme nicht über 21 geht, oder als 1, wenn sonst ein "Bust" (Überschreitung von 21) drohen würde.
#
# 5. **Hinweis 5**: Teile dem Benutzer und dem Computer jeweils 2 Karten mit der `deal_card()`-Funktion aus und füge sie mithilfe von `.append()` der jeweiligen Liste hinzu:
#
#   ```python
#   user_cards = []
#   computer_cards = []
#   ```
#
# 6. **Hinweis 6**: Erstelle eine Funktion namens `calculate_score()`, die eine Liste von Karten als Eingabe erhält und die Punktzahl zurückgibt. Nutze die `sum()`-Funktion.
#
# 7. **Hinweis 7**: Überprüfe in der Funktion `calculate_score()` auf einen Blackjack (eine Hand mit nur 2 Karten: Ass + 10) und gib `0` zurück, um einen Blackjack zu repräsentieren.
#
# 8. **Hinweis 8**: Überprüfe in `calculate_score()`, ob ein Ass (11) vorhanden ist. Wenn die Punktzahl bereits über 21 liegt, ersetze die 11 durch eine 1.
#
# 9. **Hinweis 9**: Rufe `calculate_score()` auf. Wenn der Computer oder der Benutzer einen Blackjack (`0`) hat oder die Punktzahl des Benutzers über 21 liegt, endet das Spiel.
#
# 10. **Hinweis 10**: Falls das Spiel noch nicht beendet ist, frage den Benutzer, ob er eine weitere Karte ziehen möchte. Wenn ja, füge eine weitere Karte zur `user_cards`-Liste hinzu. Wenn nein, endet das Spiel.
#
# 11. **Hinweis 11**: Überprüfe die Punktzahl nach jeder gezogenen Karte erneut und wiederhole die Überprüfungen aus Hinweis 9, bis das Spiel endet.
#
# 12. **Hinweis 12**: Sobald der Benutzer fertig ist, spielt der Computer. Der Computer zieht Karten, solange seine Punktzahl unter 17 liegt.
#
# 13. **Hinweis 13**: Erstelle eine Funktion `compare()` und übergebe ihr `user_score` und `computer_score`. Die Funktion soll folgende Regeln beachten:
#
#   - Bei gleicher Punktzahl ist es ein Unentschieden.
#
#   - Wenn der Computer einen Blackjack (`0`) hat, verliert der Benutzer.
#
#   - Wenn der Benutzer einen Blackjack (`0`) hat, gewinnt der Benutzer.
#
#   - Wenn die Punktzahl des Benutzers über 21 liegt, verliert er.
#
#   - Wenn die Punktzahl des Computers über 21 liegt, verliert der Computer.
#
#   - Ansonsten gewinnt der Spieler mit der höheren Punktzahl.
#
# 14. **Hinweis 14**: Frage den Benutzer, ob er das Spiel neu starten möchte. Wenn ja, lösche die Konsole und starte ein neues Spiel. Zeige dabei das Logo aus der Datei `art.py` an.
#
#
# Viel Erfolg! 🎉
#
# ----

# %% [markdown]
# ## Anforderungen
#
# 1. **Startkarten austeilen**:
#
#   - Teile dem Benutzer und dem Computer jeweils eine Start-Hand mit 2 zufälligen Kartenwerten aus.
# 2. **Blackjack erkennen**:
#
#   - Überprüfe, ob der Computer oder der Benutzer einen Blackjack hat (Ass + Karte mit dem Wert 10).
#
#   - Falls der Computer einen Blackjack hat, verliert der Benutzer (selbst wenn der Benutzer auch einen Blackjack hat).
#
#   - Falls der Benutzer einen Blackjack hat, gewinnt er (es sei denn, der Computer hat ebenfalls einen Blackjack).
#
# 3. **Punktzahlen berechnen**:
#
#   - Berechne die Punktzahlen des Benutzers und des Computers basierend auf den Werten ihrer Karten.
# 4. **Ass-Handhabung**:
#
#   - Wenn ein Ass gezogen wird, zähle es zunächst als 11.
#
#   - Falls die Gesamtsumme jedoch über 21 steigt, zähle das Ass als 1.
#
# 5. **Computerkarte zeigen**:
#
#   - Zeige dem Benutzer die ersten zwei Karten des Computers.
# 6. **Spielende bei bestimmten Bedingungen**:
#
#   - Das Spiel endet sofort, wenn die Punktzahl des Benutzers über 21 liegt oder wenn der Benutzer oder der Computer einen Blackjack hat.
# 7. **Weitere Karten für den Benutzer**:
#
#   - Frage den Benutzer, ob er eine weitere Karte ziehen möchte.
#
#   - Falls ja, ziehe eine weitere Karte für den Benutzer.
#
# 8. **Spielzug des Computers**:
#
#   - Sobald der Benutzer fertig ist und keine Karten mehr ziehen möchte, ist der Computer an der Reihe.
#
#   - Der Computer zieht Karten, solange seine Punktzahl unter 17 liegt.
#
# 9. **Ergebnisse vergleichen**:
#
#   - Vergleiche die Punktzahlen von Benutzer und Computer, um zu entscheiden, ob es ein Sieg, eine Niederlage oder ein Unentschieden ist.
# 10. **Endstand anzeigen**:
#
#   - Gib die endgültigen Hände und Punktzahlen des Benutzers und des Computers aus, sobald das Spiel endet.
# 11. **Spiel erneut starten**:
#
#   - Frage den Benutzer, ob er das Spiel erneut spielen möchte.
#
#   - Wenn ja, starte das Spiel von vorne.
#
#   -----

# %% [markdown]
# ## Flowchart

# %% [markdown]
# [Hier](https://drive.google.com/file/d/1hYa7uZHUqMPLK1xCbpqc_yuE7gV4BxwP/view?usp=sharing) findest du ein Flowchart, das dir bei der Logikbildung hilft

# %% [markdown]
# # ASCI Art
#
# Verwende gerne folgende ASCI ART
#
# ```
#     Willkommen zu 🃏 Blackjack! 🃏
#       ==================================
#               _____
#              |A .  | _____
#              | /.\ ||A ^  | _____
#              |(_._)|| / \ ||A _  | _____
#              |  |  || \ / || ( ) ||A_ _ |
#              |____V||  .  ||(_'_)||( v )|
#                     |____V||  |  || \ / |
#                            |____V||  .  |
#                                   |____V|
#
# ```
