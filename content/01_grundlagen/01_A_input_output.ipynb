# %% [markdown]
# # 🎯 Python Übungen: Eingabe und Ausgabe
# Jede Aufgabe enthält ein Beispiel und eine leere Code-Zelle mit einem TODO-Kommentar.

# %% [markdown]
# ## 1. Temperaturumrechnung (Celsius → Fahrenheit)
# **Aufgabe:** Frage den Benutzer nach einer Temperatur in °C und rechne sie in °F um.
#
# **Beispielausgabe:**
# ```
# Gib die Temperatur in Grad Celsius ein: 25
# 25°C entsprechen 77.0°F.
# ```

# %%
# TODO: Temperatur in Celsius einlesen und in Fahrenheit umrechnen

# %% [markdown]
# ## 2. Altersrechner
# **Aufgabe:** Frage das Geburtsjahr ab und berechne das aktuelle Alter.
#
# **Beispielausgabe:**
# ```
# In welchem Jahr wurdest du geboren? 2007
# Du bist ca. 18 Jahre alt.
# ```

# %%
# TODO: Geburtsjahr eingeben und Alter berechnen

# %% [markdown]
# ## 3. Versandkosten-Rechner
# **Aufgabe:** Berechne die Versandkosten: 5 € Grundgebühr + 1.50 € pro kg.
#
# **Beispielausgabe:**
# ```
# Wie viel wiegt dein Paket in kg? 2.5
# Dein Paket kostet 8.75 € Versand.
# ```

# %%
# TODO: Gewicht eingeben und Versandkosten berechnen

# %% [markdown]
# ## 4. Countdown in Sekunden
# **Aufgabe:** Frage nach Minuten und rechne sie in Sekunden um.
#
# **Beispielausgabe:**
# ```
# Gib eine Zeit in Minuten ein: 5
# 5 Minuten entsprechen 300 Sekunden.
# ```

# %%
# TODO: Minuten eingeben und in Sekunden umrechnen

# %% [markdown]
# ## 5. Notenschnitt berechnen
# **Aufgabe:** Frage drei Noten ab und berechne den Durchschnitt.
#
# **Beispielausgabe:**
# ```
# Note 1: 2.3
# Note 2: 3.0
# Note 3: 1.7
# Dein Notendurchschnitt ist 2.33
# ```

# %%
# TODO: Drei Noten eingeben und Durchschnitt berechnen

# %% [markdown]
# ## 6. Pizza-Teiler
# **Aufgabe:** Berechne wie viele Stücke jeder bekommt und wie viele übrig bleiben.
#
# **Beispielausgabe:**
# ```
# Wie viele Pizzastücke gibt es? 14
# Wie viele Personen essen mit? 4
# Jede Person bekommt 3 Stück(e).
# Übrig bleiben 2 Stück(e).
# ```

# %%
# TODO: Pizzastücke und Personen eingeben, Aufteilung berechnen

# %% [markdown]
# ## 7. Benzinverbrauch-Rechner
# **Aufgabe:** Berechne den Verbrauch pro 100 km.
#
# **Beispielausgabe:**
# ```
# Gefahrene Strecke in km: 300
# Verbrauchte Liter: 24
# Der Verbrauch liegt bei 8.0 l/100km.
# ```

# %%
# TODO: Strecke und Liter eingeben, Verbrauch berechnen

# %% [markdown]
# ## 8. Einkaufsrechner mit Mehrwertsteuer
# **Aufgabe:** Berechne den Gesamtpreis inkl. 19% MwSt für drei Produkte.
#
# **Beispielausgabe:**
# ```
# Produkt 1 Preis (€): 15.00
# Produkt 2 Preis (€): 12.00
# Produkt 3 Preis (€): 8.00
# Gesamtpreis inkl. MwSt: 41.65 €
# ```

# %%
# TODO: Drei Preise eingeben, Summe und MwSt berechnen

# %% [markdown]
# ## 9. Reisezeit mit Pausen
# **Aufgabe:** Berechne Fahrzeit + Pausenzeit (alle 2 Stunden 15 Minuten Pause).
#
# **Beispielausgabe:**
# ```
# Wie schnell fährst du (km/h)? 120
# Du brauchst 4.0 Stunden Fahrzeit.
# Mit 1 Pause(n) à 15 Minuten dauert die gesamte Reise ca. 4.25 Stunden.
# ```

# %%
# TODO: Geschwindigkeit eingeben, Fahrtzeit und Pausen berechnen
geschwindigkeit = float(input("Wie schnell fährst du (km/h)? "))
strecke = float(input("Wie lang ist die Strecke in km? "))

fahrzeit = strecke / geschwindigkeit

pausen = int((fahrzeit - 0.01 ) // 2)

gesamtzeit = fahrzeit + pausen * 0.25

print(f"Du brauchst {fahrzeit} Stunden Fahrzeit.")

print(f"Mit {pausen} Pause(n) à 15 Minuten dauert die gesamte Reise ca. {gesamtzeit} Stunden.")
# Out:
# Wie schnell fährst du (km/h)? 60
# Wie lang ist die Strecke in km? 480
# Du brauchst 8.0 Stunden Fahrzeit.
# Mit 3 Pause(n) à 15 Minuten dauert die gesamte Reise ca. 8.75 Stunden.

# %% [markdown]
# ## 10. Freizeitpark-Rechner
# **Aufgabe:** Berechne die Gesamtkosten für Eintritt + Snacks für mehrere Personen.
#
# **Beispielausgabe:**
# ```
# Eintritt pro Person (€): 18.50
# Wie viele Personen? 4
# Snacks pro Person (€): 6.00
# Gesamtpreis für alles: 98.0 €
# ```

# %%
# TODO: Preise und Personen eingeben, Gesamtkosten berechnen
