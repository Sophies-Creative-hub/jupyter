# %% [markdown]
# # Interaktive Übungen zu Kapitel 3: Literale und Variablen in Python

# %% [markdown]
# ## Übung 1: Finde den richtigen Typ!

# %%
# Ganzzahl (int)
alter = ___

# Gleitkommazahl (float)
preis = ___

# Wahrheitswert (bool)
ist_online = ___

# Zeichenkette (str)
stadt = ___

# Hinweis: Nutze 42, 3.99, "Berlin", False

# %% [markdown]
# ## Übung 2: Benutzerinfo anzeigen

# %%
# Benutzerinformationen speichern
vorname = "Anna"
nachname = "Schmidt"
alter = 34

# Ausgabe
print("Name:", ________)
print("Alter:", ________)

# %% [markdown]
# ## Übung 3: Falscher Code! Finde den Fehler

# %%
2stadt = "Leipzig"
temperatur = 19.5
print("In", 2stadt, "sind es", temperatur, "Grad")

# %% [markdown]
# ## Übung 4: Preise berechnen

# %%
anzahl_aepfel = 3
preis_pro_apfel = 0.75
gesamtkosten = _____________
print("Du bezahlst:", gesamtkosten, "Euro")

# %% [markdown]
# ## Übung 5: Was ist der Typ?

# %%
preis = 12.99     # Typ: __________
ist_fertig = False  # Typ: __________
name = "Lina"     # Typ: __________

# %% [markdown]
# ## Übung 6: Passwortanzeige

# %%
# TODO: Definiere zwei Variablen: benutzername und passwort

print("Benutzername:", benutzername)
print("Passwort gespeichert.")

# %% [markdown]
# ## Übung 7: Wissenschaftlich arbeiten

# %%
# TODO: Ergänze die Notation
masse_atom = _________
print("Masse:", masse_atom, "kg")

# %% [markdown]
# ## Übung 8: Lichtschalter

# %%
licht_an = True

# TODO: Ergänze die Bedingung korrekt
if ________:
    print("Licht ist an!")

# %% [markdown]
# ## Übung 9: Variablen kombinieren

# %%
vorname = "Lea"
nachname = "Becker"

# TODO: Erstelle eine neue Variable voller_name
voller_name = ______________________

print("Willkommen,", voller_name)

# %% [markdown]
# ## Übung 10: Broken Code Challenge – Was läuft hier schief?

# %%
x = 5
y = "5"
summe = x + y
print("Summe ist:", summe)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-288796453cec> in <cell line: 0>()
#       1 x = 5
#       2 y = "5"
# ----> 3 summe = x + y
#       4 print("Summe ist:", summe)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# ## Übung 11: Variable umbenennen

# %%
x1 = 12
n = "Alex"
print(n, "hat", x1, "Punkte")

# %% [markdown]
# ## Übung 12: Von Logik zu Code

# %%
# TODO: Wenn der Benutzer eingeloggt ist, zeige "Willkommen zurück!"
ist_eingeloggt = True

# %% [markdown]
# ## Übung 13: Feature Extension

# %%
anzahl_buecher = 4
anzahl_hefte = 2

# TODO: Berechne und gib die Gesamtsumme aus

# %% [markdown]
# ## Übung 14: Float oder nicht?

# %%
preis = "2.50"
anzahl = 3

# TODO: Umwandlung notwendig!
gesamt = preis * anzahl
print("Gesamtpreis:", gesamt)

# %% [markdown]
# ## Übung 15: Projektmini – Temperaturanzeige

# %%
# TODO: Zeige eine Temperaturmeldung wie:
# In Berlin sind es 23.5 Grad Celsius.
