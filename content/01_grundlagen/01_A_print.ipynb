# %% [markdown]
# ## Aufgabe 1: `print`-Anweisung ergänzen

# %% [markdown]
# Ergänze den Code, sodass `Hallo Welt!` ausgegeben wird.

# %%
print(________)

# %% [markdown]
# ## Aufgabe 2: Fehler in `print` korrigieren

# %% [markdown]
# Korrigiere den Fehler, sodass `Ich liebe Python!` korrekt ausgegeben wird.

# %%
print("Ich liebe Python!)

# %% [markdown]
# ## Aufgabe 3: Fehlende Klammern ergänzen

# %% [markdown]
# Ergänze die fehlenden Klammern, damit der Code läuft.

# %%
print "Das ist eine Übung"

# %% [markdown]
# ## Aufgabe 4: Namen ausgeben

# %% [markdown]
# Ergänze den Code, sodass dein Name ausgegeben wird.

# %%
mein_name = ____
print(mein_name)

# %% [markdown]
# ## Aufgabe 5: Fehler in String-Konkatenation korrigieren

# %% [markdown]
# Korrigiere den Code, sodass die Ausgabe `Python ist super!` erfolgt.

# %%
print("Python" + "ist" + "super!")

# %% [markdown]
# ## Aufgabe 6: Strings korrekt verketten

# %% [markdown]
# Ergänze die Zeichen, sodass `Hallo, mein Name ist Alex!` ausgegeben wird.

# %%
name = "Alex"
print("Hallo, mein Name ist" ____ name ____ )

# %% [markdown]
# ## Aufgabe 7: String-Verkettung

# %% [markdown]
# Ergänze den Code, sodass der Satz `Das ist einfach!` korrekt ausgegeben wird.

# %%
a = "Das"
b = "ist"
c = "einfach!"
print(a ____ b ____ c)

# %% [markdown]
# ## Aufgabe 8: Strings mit Zahlen kombinieren

# %% [markdown]
# Ersetze die Unterstriche, um `Python 3.11` korrekt auszugeben.

# %%
version = 3.11
print("Python" ____ version)

# %% [markdown]
# ## Aufgabe 9: Formatierte Strings mit `.format()`

# %% [markdown]
# Ergänze den Code mit `.format()`, um `Mein Lieblingszahl ist 42` auszugeben.

# %%
zahl = 42
print("Mein Lieblingszahl ist {}"._________)

# %% [markdown]
# ## Aufgabe 10: F-Strings verwenden

# %% [markdown]
# Ergänze den Code mit einem f-String, um `Mein Alter ist 25` auszugeben.

# %%
alter = 25
print(_________)

# %% [markdown]
# ## Aufgabe 11: Addition durchführen

# %% [markdown]
# Ergänze den Code, um die Summe von `7` und `3` auszugeben.

# %%
print(____ + ____)

# %% [markdown]
# ## Aufgabe 12: Subtraktion durchführen

# %% [markdown]
# Ergänze den Code, sodass die Differenz von `15 - 4` ausgegeben wird.

# %%
print(____ - ____)

# %% [markdown]
# ## Aufgabe 13: Multiplikation durchführen

# %% [markdown]
# Ergänze den Code, sodass das Produkt von `6 * 7` ausgegeben wird.

# %%
print(____ * ____)

# %% [markdown]
# ## Aufgabe 14: Division durchführen

# %% [markdown]
# Ergänze den Code, sodass das Ergebnis von `25 / 5` korrekt ausgegeben wird.

# %%
print(____ / ____)

# %% [markdown]
# ## Aufgabe 15: Potenz berechnen

# %% [markdown]
# Ergänze den Code, sodass `10 hoch 3` korrekt berechnet wird.

# %%
print(____ ** ____)

# %% [markdown]
# ## Aufgabe 16: Zahl mit String kombinieren

# %% [markdown]
# Ergänze den Code, sodass `Das Ergebnis ist 50` ausgegeben wird.

# %%
ergebnis = 50
print("Das Ergebnis ist " ____ ergebnis)

# %% [markdown]
# ## Aufgabe 17: Gerundete Werte ausgeben

# %% [markdown]
# Ergänze den Code, um eine Division und einen gerundeten Wert auszugeben.

# %%
zahl = 10 / 3
print("Das gerundete Ergebnis ist {:.2f}"._________)

# %% [markdown]
# ## Aufgabe 18: Zukunftsberechnung

# %% [markdown]
# Ergänze den Code, sodass `In 5 Jahren bin ich 30` ausgegeben wird.

# %%
alter = 25
print(_________)

# %% [markdown]
# ## Aufgabe 19: Rechenoperation mit f-String ausgeben

# %% [markdown]
# Ergänze den Code, sodass `10 + 20 = 30` korrekt ausgegeben wird.

# %%
a = 10
b = 20
print(f"____ + ____ = ____")

# %% [markdown]
# ## Aufgabe 20: Eigene Werte in f-String einfügen

# %% [markdown]
# Ergänze den Code, sodass `Mein Name ist Alex und ich bin 30 Jahre alt.` mit einem **f-String** ausgegeben wird.

# %%
name = "Alex"
alter = 30
print(_________)
