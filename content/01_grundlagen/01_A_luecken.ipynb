# %% [markdown]
# # 🧠 Hausaufgabe: 10 Python-Übungen mit Lücken
#
# Fülle die fehlenden Teile im Code aus.

# %% [markdown]
# ## 1. Lieblingsgetränk
# Frage nach dem Namen und Lieblingsgetränk der Person und gib einen Satz aus. Ergänze den fehlenden Ausdruck.

# %%
name = input("Wie heißt du?")
getraenk = input("Was ist dein Lieblingsgetränk? ")
print(name + " trinkt gerne " + _______ + ".")
# Out:
# Wie heißt du?Galina
# Was ist dein Lieblingsgetränk? Tee
# Galina trinkt gerne Tee.

# %% [markdown]
# ## 2. Taschengeld berechnen
# Frage, wie viel Euro du pro Woche bekommst. Rechne den Monatsbetrag aus (4 Wochen). Ergänze die Berechnung.

# %%
woche = input("Wieviel Euro bekommst du pro Woche? ")
monat = int(woche) * _____
print("Im Monat bekommst du " + str(monat) + " Euro.")

# %% [markdown]
# ## 3. Päckchen stapeln
# Frage nach der Anzahl von Päckchen. Jedes ist 12 cm hoch. Berechne die Gesamthöhe.

# %%
anzahl = _____("Wie viele Päckchen hast du? ")
hoehe = int(anzahl) * 12
print("Der Stapel ist " + str(_____) + " cm hoch.")

# %% [markdown]
# ## 4. Sandwich-Zutaten
# Frage nach zwei Lieblingszutaten für ein Sandwich und gib sie aus. Ergänze die Eingaben und die Ausgabe.

# %%
_____ = input("Erste Zutat: ")
_____ = input("Zweite Zutat: ")
print("Ein leckeres Sandwich mit " + zutat1 + " und " + zutat2 + ".")

# %% [markdown]
# ## 5. Ballonkette
# Frage nach der Anzahl der Ballons. Jeder ist 30 cm groß. Ergänze alle Schritte.

# %%
ballons = _____("Wie viele Ballons hast du? ")
_____ = int(ballons) * 30
print("Die Ballonkette ist " + str(laenge) + " cm lang.")

# %% [markdown]
# ## 6. Leseliste
# Frage nach drei Buchtiteln und gib eine Leseliste aus. Ergänze den Code vollständig.

# %%
buch1 = _____("Erster Buchtitel: ")
buch2 = _____("Zweiter Buchtitel: ")
buch3 = _____("Dritter Buchtitel: ")
print("Deine Leseliste:")
print("1. " + _____)
print("2. " + _____)
print("3. " + _____)

# %% [markdown]
# ## 7. Kuchenstücke verteilen
# Frage nach Kuchenstücken und Personen. Ergänze alle Berechnungen und Ausgaben.

# %%
______ = ______("Wieviele Kuchenstücke? ")
personen = input("Wieviele Personen? ")
_____ = int(stuecke) // ___(personen)
print("Jede Person bekommt " + str(pro_person) + " Stück(e).")

# %% [markdown]
# ## 8. Radtour-Dauer
# Frage nach Minuten und rechne in Stunden. Ergänze alle Berechnungen.

# %%
minuten = input__"Wie lange warst du unterwegs (in Minuten)? "__
_____ = int(minuten) / 60
print("Das sind " + str(stunden) + " Stunden.")

# %% [markdown]
# ## 9. Seifenblasen zählen
# Frage nach einer Anzahl und gib eine passende Nachricht aus. Ergänze alle Teile.

# %%
blasen = _____("Wie viele Seifenblasen hast du gemacht? ")
_____("Wow! " + blasen + " Seifenblasen – das macht Spaß!")

# %% [markdown]
# ## 10. Getränkepreise zusammenrechnen
# Frage zwei Preise ab und berechne den Gesamtpreis. Ergänze die Eingaben, Berechnung und Ausgabe.

# %%
preis1 = _____ __"Preis des ersten Getränks: "__
preis2 = _____ __"Preis des zweiten Getränks: "__
gesamt = _____ __preis1__ + float __preis2__
print("Gesamtpreis: " + str(_____) + " €")
