# %% [markdown]
# ## Aufgabe 1: Einführung in Floats

# %% [markdown]
# Ergänze den Code, sodass die Variable `x` die Gleitkommazahl `3.14` speichert.

# %%
x = ____
print(x)

# %% [markdown]
# ## Aufgabe 2: Fehler in Float-Darstellung korrigieren

# %% [markdown]
# Korrigiere den Code, sodass `5.5` korrekt als Gleitkommazahl gespeichert wird.

# %%
zahl = 5,5
print(zahl)

# %% [markdown]
# ## Aufgabe 3: Division als Float speichern

# %% [markdown]
# Ergänze den Code, sodass das Ergebnis der Division `10 / 4` als Float gespeichert wird.

# %%
ergebnis = 10 ____ 4
print(ergebnis)  # Erwartete Ausgabe: 2.5

# %% [markdown]
# ## Aufgabe 4: Addition mit Floats

# %% [markdown]
# Ergänze den Code, um die Summe von `2.5` und `3.75` zu berechnen.

# %%
print(____ + ____)

# %% [markdown]
# ## Aufgabe 5: Multiplikation mit Floats

# %% [markdown]
# Ergänze den Code, um das Produkt von `4.2` und `3.0` zu berechnen.

# %%
print(____ * ____)

# %% [markdown]
# ## Aufgabe 6: Quadrat eines Floats berechnen

# %% [markdown]
# Ergänze den Code, um das Quadrat von `1.5` zu berechnen.

# %%
zahl = 1.5
print(____ ** ____)

# %% [markdown]
# ## Aufgabe 7: Float-Division

# %% [markdown]
# Ergänze den Code, sodass `25.0 / 4.0` berechnet und korrekt ausgegeben wird.

# %%
print(____ / ____)

# %% [markdown]
# ## Aufgabe 8: Restwert mit Floats berechnen

# %% [markdown]
# Ergänze den Code, um den **Restwert** der Division `7.5 % 2.0` zu berechnen.

# %%
print(____ % ____)

# %% [markdown]
# ## Aufgabe 9: Floats runden

# %% [markdown]
# Ergänze den Code, um `3.14159` auf **zwei Nachkommastellen** zu runden.

# %%
pi = 3.14159
print(round(pi, ____))

# %% [markdown]
# ## Aufgabe 10: Abrunden von Floats

# %% [markdown]
# Ergänze den Code, um eine Zahl **abzurunden**. Hilfe: https://www.w3schools.com/python/module_math.asp

# %%
import math
zahl = 4.9
print(math.____(zahl))  # Erwartete Ausgabe: 4

# %% [markdown]
# ## Aufgabe 11: Aufrunden von Floats

# %% [markdown]
# Ergänze den Code, um eine Zahl **aufzurunden**. Hilfe: https://www.w3schools.com/python/module_math.asp

# %%
import math
zahl = 4.1
print(math.____(zahl))  # Erwartete Ausgabe: 5

# %% [markdown]
# ## Aufgabe 12: F-Strings mit Floats

# %% [markdown]
# Ergänze den Code, um `f-strings` zu verwenden und `Pi beträgt ungefähr 3.14` auszugeben.

# %%
pi = 3.14159
print(f"Pi beträgt ungefähr {____:.2f}")

# %% [markdown]
# ## Aufgabe 13: Preis mit zwei Nachkommastellen anzeigen

# %% [markdown]
# Ergänze den Code, um den Preis in Euro auf zwei Nachkommastellen anzuzeigen.

# %%
preis = 19.995
print(f"Der Preis beträgt {preis:.2f} €")
# Out:
# Der Preis beträgt 20.00 €

# %% [markdown]
# ## Aufgabe 14: Einführung in Booleans

# %% [markdown]
# Ergänze den Code, sodass `True` gespeichert und ausgegeben wird.

# %%
wahrheit = ____
print(wahrheit)

# %% [markdown]
# ## Aufgabe 15: Vergleichsoperatoren mit Booleans

# %% [markdown]
# Ergänze den Code, um zu überprüfen, ob `10 größer als 5` ist.

# %%
print(10 ____ 5)  # Erwartete Ausgabe: True

# %% [markdown]
# ## Aufgabe 16: Gleichheitsprüfung mit Booleans

# %% [markdown]
# Ergänze den Code, um den Wahrheitswert einer Gleichheitsprüfung zu speichern.

# %%
ist_gleich = (10 ____ 10)
print(ist_gleich)  # Erwartete Ausgabe: True

# %% [markdown]
# ## Aufgabe 17: Ungleichheitsprüfung mit Booleans

# %% [markdown]
# Ergänze den Code, um den Wahrheitswert einer Ungleichheitsprüfung auszugeben.

# %%
print(8 ____ 10)  # Erwartete Ausgabe: True

# %% [markdown]
# ## Aufgabe 18: Boolean mit f-Strings verwenden

# %% [markdown]
# Ergänze den Code, um `Das ist wahr: True` mit einem f-String auszugeben.

# %%
wahrheit = True
print(f"Das ist wahr: {____}")

# %% [markdown]
# ## Aufgabe 19: Kombination von Floats und Booleans

# %% [markdown]
# Ergänze den Code, sodass geprüft wird, ob `3.14` kleiner als `3.15` ist.

# %%
print(3.14 ____ 3.15)  # Erwartete Ausgabe: True

# %% [markdown]
# ## Aufgabe 20: Wahrheitswerte mit logischen Operatoren kombinieren

# %% [markdown]
# Ergänze den Code, um zwei Wahrheitswerte mit `and` zu kombinieren.

# %%
print(True ____ False)  # Erwartete Ausgabe: False
