# %% [markdown]
# ## Aufgabe 1: Länge eines Strings

# %% [markdown]
# Ergänze den Code, um die Länge des Strings zu bestimmen.

# %%
text = "Python ist großartig!"
laenge = ____
print(laenge)  # Erwartete Ausgabe: 21

# %% [markdown]
# ## Aufgabe 2: Ersten Buchstaben extrahieren

# %% [markdown]
# Ergänze den Code, um den ersten Buchstaben eines Strings zu extrahieren.

# %%
wort = "Python"
erster_buchstabe = ____
print(erster_buchstabe)  # Erwartete Ausgabe: P

# %% [markdown]
# ## Aufgabe 3: Letzte drei Zeichen extrahieren

# %% [markdown]
# Ergänze den Code, um die letzten drei Zeichen eines Strings zu extrahieren.

# %%
satz = "Programmieren"
letzte_drei = ____
print(letzte_drei)  # Erwartete Ausgabe: ren

# %% [markdown]
# ## Aufgabe 4: String in Großbuchstaben umwandeln

# %% [markdown]
# Ergänze den Code, um einen String in Großbuchstaben umzuwandeln.

# %%
text = "python"
gross = ____
print(gross)  # Erwartete Ausgabe: PYTHON

# %% [markdown]
# ## Aufgabe 5: String in Kleinbuchstaben umwandeln

# %% [markdown]
# Ergänze den Code, um einen String in Kleinbuchstaben umzuwandeln.

# %%
text = "HELLO WORLD"
klein = ____
print(klein)  # Erwartete Ausgabe: hello world

# %% [markdown]
# ## Aufgabe 6: Leerzeichen entfernen

# %% [markdown]
# Ergänze den Code, um Leerzeichen am Anfang und Ende eines Strings zu entfernen.

# %%
text = "  Python  "
sauber = ____
print(sauber)  # Erwartete Ausgabe: Python

# %% [markdown]
# ## Aufgabe 7: String-Anfang überprüfen

# %% [markdown]
# Ergänze den Code, um zu überprüfen, ob ein String mit "Hallo" beginnt.

# %%
satz = "Hallo, Welt!"
beginnt_mit_hallo = ____
print(beginnt_mit_hallo)  # Erwartete Ausgabe: True

# %% [markdown]
# ## Aufgabe 8: String-Ende überprüfen

# %% [markdown]
# Ergänze den Code, um zu überprüfen, ob ein String mit "!" endet.

# %%
satz = "Das ist großartig!"
endet_mit_ausrufezeichen = ____
print(endet_mit_ausrufezeichen)  # Erwartete Ausgabe: True

# %% [markdown]
# ## Aufgabe 9: Zeichen ersetzen

# %% [markdown]
# Ergänze den Code, um alle "a" in einem String durch "o" zu ersetzen.

# %%
text = "Apfel und Banane"
ersetzt = ____
print(ersetzt)  # Erwartete Ausgabe: Opfel und Bonone

# %% [markdown]
# ## Aufgabe 10: Wort in String suchen

# %% [markdown]
# Ergänze den Code, um zu überprüfen, ob ein bestimmtes Wort im Satz enthalten ist.

# %%
satz = "Das ist ein tolles Python-Tutorial."
enthaelt_python = ____
print(enthaelt_python)  # Erwartete Ausgabe: True

# %% [markdown]
# ## Aufgabe 11: Anzahl eines Zeichens zählen

# %% [markdown]
# Ergänze den Code, um die Anzahl der Vorkommen von "o" in einem String zu zählen.

# %%
text = "Hallo, wie oft kommt das o vor?"
anzahl_o = ____
print(anzahl_o)  # Erwartete Ausgabe: 3

# %% [markdown]
# ## Aufgabe 12: String in Wörter teilen

# %% [markdown]
# Ergänze den Code, um einen String an jedem Leerzeichen zu trennen.

# %%
satz = "Python ist eine tolle Sprache"
woerter = ____
print(woerter)  # Erwartete Ausgabe: ['Python', 'ist', 'eine', 'tolle', 'Sprache']

# %% [markdown]
# ## Aufgabe 13: Wörter zu einem Satz verbinden

# %% [markdown]
# Ergänze den Code, um aus einer Liste von Wörtern einen einzigen String mit Leerzeichen zu erstellen.

# %%
woerter = ["Python", "ist", "super"]
satz = ____
print(satz)  # Erwartete Ausgabe: Python ist super

# %% [markdown]
# ## Aufgabe 14: String formatieren

# %% [markdown]
# Ergänze den Code, um einen String so zu formatieren, dass `name` und `alter` eingefügt werden.

# %%
name = "Anna"
alter = 25
satz = ____
print(satz)  # Erwartete Ausgabe: Mein Name ist Anna und ich bin 25 Jahre alt.

# %% [markdown]
# ## Aufgabe 15: Position eines Zeichens finden

# %% [markdown]
# Ergänze den Code, um die Position des ersten "e" in einem String zu finden.

# %%
text = "Elefant"
position_e = ____
print(position_e)  # Erwartete Ausgabe: 1

# %% [markdown]
# ## Aufgabe 16: Zeichen in neuer Zeile ausgeben

# %% [markdown]
# Ergänze den Code, um jedes Zeichen eines Strings auf einer neuen Zeile auszugeben.

# %%
wort = "Python"
for buchstabe in ____:
    print(buchstabe)

# %% [markdown]
# ## Aufgabe 17: Großbuchstaben extrahieren

# %% [markdown]
# Ergänze den Code, um alle Großbuchstaben aus einem String zu extrahieren.

# %%
satz = "Hallo WELT, wie geht es DIR?"
grossbuchstaben = ""
for buchstabe in ____:
    if ____:
        grossbuchstaben += buchstabe
print(grossbuchstaben)  # Erwartete Ausgabe: HELTDIR

# %% [markdown]
# ## Aufgabe 18: String umkehren

# %% [markdown]
# Ergänze den Code, um einen String umzukehren.

# %%
text = "Python"
umgekehrt = ____
print(umgekehrt)  # Erwartete Ausgabe: nohtyP

# %% [markdown]
# ## Aufgabe 19: Vokale entfernen

# %% [markdown]
# Ergänze den Code, um alle Vokale aus einem String zu entfernen.

# %%
text = "Programmieren macht Spaß"
ohne_vokale = ""
for buchstabe in ____:
    if buchstabe not in "aeiouAEIOU":
        ohne_vokale += buchstabe
print(ohne_vokale)  # Erwartete Ausgabe: Prgrmmrn mcht Spß

# %% [markdown]
# ## Aufgabe 20: Palindromprüfung

# %% [markdown]
# Ergänze den Code, um zu prüfen, ob ein Wort ein Palindrom ist (vorwärts und rückwärts gleich).

# %%
wort = "racecar"
ist_palindrom = ____
print(ist_palindrom)  # Erwartete Ausgabe: True
