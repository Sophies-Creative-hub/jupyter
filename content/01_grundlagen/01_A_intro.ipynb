# %% [markdown]
# ## Aufgabe 1: Fehlende Zeichen ergänzen

# %% [markdown]
# Ergänze die fehlenden Zeichen, sodass der Code korrekt ist.

# %%
print(Hallo, Welt!)

# %% [markdown]
# ## Aufgabe 2: Anführungszeichen ergänzen

# %% [markdown]
# Ergänze die fehlenden Anführungszeichen, sodass der Code funktioniert.

# %%
print(_________)

# %% [markdown]
# ## Aufgabe 3: Variablenzuweisung korrigieren

# %% [markdown]
# Ergänze das fehlende Gleichheitszeichen in der Variablenzuweisung.

# %%
name "Alice"
print(name)

# %% [markdown]
# ## Aufgabe 4: Fehler in der `print`-Funktion korrigieren

# %% [markdown]
# Korrigiere den Fehler, sodass die Ausgabe funktioniert.

# %%
print "Python ist toll!"

# %% [markdown]
# ## Aufgabe 5: Variablenreferenz korrigieren

# %% [markdown]
# Korrigiere die fehlerhafte Variablenreferenz.

# %%
zahl = 10
print(Zahl)

# %% [markdown]
# ## Aufgabe 6: Fehlerhafte String-Syntax korrigieren

# %% [markdown]
# Korrigiere die fehlerhafte String-Syntax.

# %%
text = "Das ist ein Fehler
print(text)

# %% [markdown]
# ## Aufgabe 7: Variablenzuweisung ergänzen

# %% [markdown]
# Ergänze den Code, sodass `Python` korrekt als Wert in `sprache` gespeichert wird.

# %%
sprache ___ "Python"
print(sprache)

# %% [markdown]
# ## Aufgabe 8: Fehlende Zuweisung ergänzen

# %% [markdown]
# Ergänze die fehlende Zuweisung, sodass `x` im `print`-Befehl ausgegeben wird.

# %%
x = ___
print(x)

# %% [markdown]
# ## Aufgabe 9: Gültige Variablennamen

# %% [markdown]
# Ergänze die gültige Variable, sodass keine Fehler auftreten.

# %%
mein_name = "Lisa"
wert2 = 100
_geheim = "versteckt"
if = 42  # Diese Zeile führt zu einem Fehler! Korrigiere sie.

# %% [markdown]
# ## Aufgabe 10: Unterschied zwischen `print` einer Variable und eines Strings

# %% [markdown]
# Ergänze den Code so, dass einmal der **Buchstabe x** und einmal der **Wert von x** ausgegeben wird.

# %%
x = 5
print(____)  # Ausgabe: x
print(____)  # Ausgabe: 5

# %% [markdown]
# ## Aufgabe 11: String-Konkatenation korrigieren

# %% [markdown]
# Ergänze den Code, sodass `Hallo Peter` ausgegeben wird.

# %%
name = "Peter"
print(_____ + name)

# %% [markdown]
# ## Aufgabe 12: Unterschied zwischen Zahlen und Strings

# %% [markdown]
# Ergänze den Code, sodass `a + a` eine Zahl und `b + b` einen String ausgibt.

# %%
a = ____
b = "3"
print(a + a)  # Erwartete Ausgabe: 6
print(b + b)  # Erwartete Ausgabe: "33"

# %% [markdown]
# ## Aufgabe 13: Fehlende Werte ergänzen

# %% [markdown]
# Ergänze die fehlenden Werte.

# %%
zahl = ____
text = "Python"
print(zahl)
print(____)

# %% [markdown]
# ## Aufgabe 14: String-Verkettung

# %% [markdown]
# Ergänze den Code, sodass der Satz `Ich lerne Python!` korrekt ausgegeben wird.

# %%
wort1 = "Ich"
wort2 = "lerne"
wort3 = "Python!"
print(________________)

# %% [markdown]
# ## Aufgabe 15: Strings mit Operatoren verknüpfen

# %% [markdown]
# Ergänze die fehlenden Operatoren, sodass `Python ist toll!` ausgegeben wird.

# %%
a = "Python"
b = "ist"
c = "toll!"
print(a ___ b ___ c)

# %% [markdown]
# ## Aufgabe 16: Rechnen mit Zahlen

# %% [markdown]
# Ergänze das fehlende Plus-Zeichen, um 15 auszugeben.

# %%
x = 10
y = 5
ergebnis = x ____ y
print(ergebnis)  # Erwartete Ausgabe: 15

# %% [markdown]
# ## Aufgabe 17: Quadrat einer Zahl berechnen

# %% [markdown]
# Ergänze den Code, um das Quadrat einer Zahl auszugeben.

# %%
zahl = 4
print(____ * ____)

# %% [markdown]
# ## Aufgabe 18: Fehlerhafte Kommentare korrigieren

# %% [markdown]
# Dieser Code gibt nichts aus. Korrigiere ihn, sodass `'Hallo!'` sichtbar wird.

# %%
# print("Hallo!")  # Entferne das Kommentarzeichen, um die Ausgabe zu aktivieren.

# %% [markdown]
# ## Aufgabe 19: Fehlerhafte Variablennutzung korrigieren

# %% [markdown]
# Korrigiere den Fehler im Code, sodass keine `NameError`-Meldung mehr auftritt.

# %%
zahl = 10
print(zahl)
print(some_text)  # Diese Zeile führt zu einem Fehler! Definiere `text` vorher.
# Out:
# 10
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3292a961a2c8> in <cell line: 0>()
#       1 zahl = 10
#       2 print(zahl)
# ----> 3 print(some_text)  # Diese Zeile führt zu einem Fehler! Definiere `text` vorher.
#
# NameError: name 'some_text' is not defined

# %% [markdown]
# ## Aufgabe 20: Eigenes Programm schreiben

# %% [markdown]
# Schreibe ein eigenes kleines Programm, das deinen Namen speichert und mit `print` ausgibt.

# %%
# Deinen Code hier schreiben:
