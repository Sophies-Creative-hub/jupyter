# %% [markdown]
# ### Aufgabe 1: Einfache Rechenoperationen
# Was wird ausgegeben?
#
# # Deine Vermutung: ___

# %%
a = 5
b = 10
c = a + b
print(c)
# Out:
# 15

# %% [markdown]
# ### Aufgabe 2: Überschreibung einer Variable
# Was wird ausgegeben?
#
# # Deine Vermutung: ___

# %%
x = 3
x = x + 7
x = x * 2
print(x)
# Out:
# 20

# %% [markdown]
# ### Aufgabe 3: Drei Variablen, eine wird überschrieben
# Was wird ausgegeben?
#
# # Deine Vermutung: ___

# %%
a = 2
b = 4
c = a + b # c = 6
b = b + 3 # b = 7
c = a + b # c = 9
print(c)
# Out:
# 9

# %% [markdown]
# ### Aufgabe 4: Kettenreaktion mit vier Variablen
# Was wird ausgegeben?
#
# # Deine Vermutung: ___

# %%
x = 1
y = 2
z = x + y # z = 3
w = z * 3 # w = 9
x = x + w # x = 10
print(x)
# Out:
# 10

# %% [markdown]
# ### Aufgabe 5: Variablen mehrfach überschrieben
# Was wird ausgegeben?
#
# # Deine Vermutung: ___

# %%
a = 10
b = 5
a = a - b # a = 5
b = a + b # b = 10
a = b * 2 # a = 20
print(a)
# Out:
# 20

# %% [markdown]
# ### Aufgabe 6: Kombination aus Addition und Division
# Was wird ausgegeben?
#
# # Deine Vermutung: ___

# %%
a = 20
b = 10
c = a + b  # c = 30
a = c // 5 # a = 6
print(a)
# Out:
# 6

# %% [markdown]
# ### Aufgabe 7: Vier Variablen mit Wechselwirkung
# Was wird ausgegeben?
#
# # Deine Vermutung: ___

# %%
x = 2
y = 4
z = x + y # z = 6
w = z + 1 # w = 7
z = w + x # z = 9
print(z)
# Out:
# 9

# %% [markdown]
# ### Aufgabe 8: Verdopplung und Subtraktion
# Was wird ausgegeben?
#
# # Deine Vermutung: ___

# %%
a = 3
b = a * 2 # b = 6
c = b - 1 # c = 5
a = c + 4 # a = 9
print(a)
# Out:
# 9

# %% [markdown]
# ### Aufgabe 9: Alles wird neu berechnet
# Was wird ausgegeben?
#
# # Deine Vermutung: ___

# %%
x = 100
y = 50
z = x - y # z = 50
x = z * 2 # x = 100
y = x + z # y = 150
print(y)
# Out:
# 150

# %% [markdown]
# ### Aufgabe 10: Aufeinanderfolgende Änderungen
# Was wird ausgegeben?
#
# # Deine Vermutung: ___

# %%
a = 1
b = 2
c = 3
a = b + c # a = 5
b = a + c # b = 8
c = a + b # c = 13
print(c)
# Out:
# 13
