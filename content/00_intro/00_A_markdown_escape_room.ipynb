# %% [markdown]
# # 🗝️ Markdown Escape Room – Die verlorene Datei
#
# Willkommen zu deinem Markdown-Escape-Room-Abenteuer!
# Du bist in einem mysteriösen Computer gefangen. Nur wer die Markdown-Rätsel löst,
# kann die versteckte Datei finden und entkommen.
#
# Jede Szene enthält eine Aufgabe, die du mit **Markdown-Syntax** beantworten musst.
# Schreibe deine Lösung in den **folgenden Textblock** direkt darunter.
#
# Viel Erfolg – und pass auf versteckte Hinweise auf! 👀

# %% [markdown]
# ## 🔐 Szene 1: Der Begrüßungsbildschirm
#
# Ein alter Terminal flackert auf und zeigt:
# > "Nur wer seinen Namen kennt, darf weitergehen."
#
# **Aufgabe:**
# - Schreibe deinen Namen als Überschrift (Ebene 1)
# - Schreibe darunter einen kurzen Satz über dich
# - Füge eine Liste mit 3 Dingen hinzu, die du gut kannst

# %% [markdown]
# **Bearbeite deine Antwort hier:**

# %% [markdown]
# ## 🧱 Szene 2: Die verschlossene Tür
#
# Ein Hinweis an der Wand leuchtet auf:
# > "Nur wer die Formatierung beherrscht, kann durch die Tür gehen."
#
# **Aufgabe:**
# - Schreibe drei deiner Lieblingsfilme in einer nummerierten Liste
# - Mache den besten Film **fett**
# - Mache deinen Geheimtipp *kursiv*
# - Verlinke einen Trailer auf YouTube

# %% [markdown]
# **Bearbeite deine Antwort hier:**

# %% [markdown]
# ## 🕸️ Szene 3: Die Bibliothek der Tabellen
#
# In der Ecke des Raumes steht ein altes Buch mit der Aufschrift:
# > "Ordne dein Wissen in Spalten, und der Pfad wird klar."
#
# **Aufgabe:**
# - Erstelle eine Tabelle mit 3 Ländern, die du bereisen möchtest:
#   | Land | Grund | Schon besucht? |
#   |------|-------|----------------|
#   | ...  | ...   | ...            |

# %% [markdown]
# **Bearbeite deine Antwort hier:**

# %% [markdown]
# ## 🔥 Szene 4: Das Rätsel der Elemente
#
# Ein altes Terminal fragt:
# > "Welche Elemente kennst du wirklich?"
#
# **Aufgabe:**
# - Schreibe einen Satz in einem **Blockzitat**
# - Erstelle einen Codeblock, der den Befehl `echo "Hallo Welt"` enthält
# - Erstelle eine Aufgabenliste mit drei Dingen, die du heute schon erledigt hast (`- [x]`)

# %% [markdown]
# **Bearbeite deine Antwort hier:**

# %% [markdown]
# ## 🏁 Finale: Die Datei erscheint
#
# Plötzlich erscheint auf dem Bildschirm:
# > "Erstelle deine eigene Markdown-Seite."
#
# **Aufgabe:**
# - Gib deinem Abenteuer einen Titel (Ebene 1)
# - Füge eine kurze Zusammenfassung deiner Flucht hinzu
# - Nutze mindestens **eine Liste**, *eine kursive Stelle*, einen **Link** und ein `Codebeispiel`

# %% [markdown]
# **Bearbeite deine Antwort hier:**
