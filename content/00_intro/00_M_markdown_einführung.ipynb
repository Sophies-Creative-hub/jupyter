# %% [markdown]
# Markdown-Spickzettel
#
# Verschiedene Überschriften
#
# # 1. Überschrift 1
# ## 1.1 Überschrift 2
# ### 1.1.1 Überschrift 3
# #### Überschrift 4
# ##### Überschrift 5
# ###### Überschrift 6
#
#
# **fett**
#
# *kursiv*
#
# ***fett und kursiv***
#
# ~~durchgestrichen~~
#
# <u>Unterstrichener Text</u>
#
#
# > Hier ist meine Zitat.

# %% [markdown]
# Ungeordnete Liste:
# - Punkt A
# - Punkt B
#   - Unterpunkt
#
# Geordnete Liste:
# 1. Erster Punkt
# 2. Zweiter Punkt
#   - Unterpunkt
#
# Aufgabenliste (Checkliste)
# - [ ] Offene Aufgabe
# - [x] Erledigte Aufgabe

# %% [markdown]
# [Unser Classroom](https://classroom.google.com/c/NzUzOTQ3MTg4OTk4)
#
# ![Mein Bild](https://picsum.photos/300/200)

# %% [markdown]
# |Tier|Farbe|Größe|
# |----|----|----|
# |Katze|Grau|klein|
# |Hund|Braun|Groß|

# %% [markdown]
# Inline Code: Der Text hat ein Codebeispiel: `print("Hello World!")`. Hier folgt die Bedeutung von diesem Codebeispiel.
#
# Mehrzeiliger Codeblock:
# ```
# def hallo():
#   print("Hello World!")
# ```
# Hier folgt weiterer Text.

# %% [markdown]
# Zeile 1.
#
# Zeile 2. Man braucht eine Leerzeile zwischen den beiden Zeilen, damit sie separat angezeigt werden.
