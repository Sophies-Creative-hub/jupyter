# %% [markdown]
# ### Aufgabe 1: Lücke füllen
# Frage den Namen ab und gib ihn aus.

# %%
name = input("Wie heißt du?")
# Ergänze unten:
# Out:
# Wie heißt du?Galina

# %% [markdown]
# ### Aufgabe 2: Zeile ergänzen
# Frage zwei Zahlen ab und berechne die Summe.

# %%
a = input("Erste Zahl: ")
b = input("Zweite Zahl: ")
# Ergänze hier:

# %% [markdown]
# ### Aufgabe 3: Code reparieren
# Der Code soll zwei Zahlen addieren.

# %%
a = input("Zahl 1: ")
b = input("Zahl 2: ")
ergebnis = a + b  # Korrigiere diesen Ausdruck

# %% [markdown]
# ### Aufgabe 4: Code vervollständigen
# Gib aus, ob jemand volljährig ist.

# %%
alter = int(input("Wie alt bist du?"))

if alter >= 18:
    print("Du bist volljährig.")
else:
    # Ergänze hier

# %% [markdown]
# ### Aufgabe 5: Code selbst schreiben
# Gib aus, ob eine Zahl größer als 10 ist.

# %%
# Schreibe deinen Code hier

# %% [markdown]
# ### Aufgabe 6: Lücke füllen
# Temperatur beurteilen.

# %%
temperatur = float(input("Temperatur in °C: "))

if temperatur > 30:
    print("Es ist sehr heiß.")
elif temperatur > 20:
    # Ergänze hier
else:
    print("Es ist kühl.")

# %% [markdown]
# ### Aufgabe 7: Zeile ergänzen
# Vergleiche zwei Zahlen und gib die größere aus.

# %%
a = float(input("Zahl 1: "))
b = float(input("Zahl 2: "))

if a > b:
    print("Die größere Zahl ist", a)
elif b > a:
    # Ergänze hier
else:
    print("Beide Zahlen sind gleich.")

# %% [markdown]
# ### Aufgabe 8: Logikfehler korrigieren
# Kategorisiere Alter korrekt.

# %%
alter = int(input("Alter: "))

if alter > 12:
    print("Kind")
elif alter > 18:
    print("Teenager")
else:
    print("Erwachsen")  # Korrigiere die Logik

# %% [markdown]
# ### Aufgabe 9: Lücke füllen
# Beantworte die Hungerfrage.

# %%
antwort = input("Hast du Hunger? (ja/nein): ")

if antwort == "ja":
    print("Dann iss etwas!")
else:
    # Ergänze hier

# %% [markdown]
# ### Aufgabe 10: Code selbst schreiben
# Gib eine Nachricht zur Lieblingsfarbe aus.
#
# Zum Beispiel, der Benutzer gibt "blau" ein, und bekommt eine Assoziation: "Die Farbe Blau wird oft mit Ruhe, Vertrauen und Klarheit assoziiert. "
#
# "rot" - "Die Farbe Rot symbolisiert Energie, Leidenschaft und Kraft. "
#
# usw.

# %%
# Schreibe deinen Code hier
