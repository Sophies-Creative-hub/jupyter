# %% [markdown]
# ### Aufgabe 1 – Zählen bis 5
# **Beschreibung:**
# Ergänze die Bedingung, sodass von 1 bis 5 gezählt wird.

# %%
x = 1
while __________________:
    print(x)
    x = x + 1

# %% [markdown]
# ### Aufgabe 2 – Eingabe wiederholen, bis „ja“
# **Beschreibung:**
# Wiederhole die Eingabeaufforderung, bis der Benutzer 'ja' eingibt.

# %%
antwort = ""
while __________________:
    antwort = input("Willst du fortfahren? (ja/nein): ")

# %% [markdown]
# ### Aufgabe 3 – Passwort abfragen
# **Beschreibung:**
# Frage so lange nach dem Passwort, bis etwas eingegeben wurde.

# %%
pw = ""
while __________________:
    pw = input("Bitte Passwort eingeben: ")

# %% [markdown]
# ### Aufgabe 4 – Zähle von 10 rückwärts
# **Beschreibung:**
# Zähle von 10 bis 1 rückwärts.

# %%
x = 10
while __________________:
    print(x)
    x = x - 1

# %% [markdown]
# ### Aufgabe 5 – Nur bei falschem Code
# **Beschreibung:**
# Frage so lange nach dem Code, bis der richtige eingegeben wurde (z. B. 'abc123').

# %%
code = ""
while __________________:
    code = input("Gib den Code ein: ")

# %% [markdown]
# ### Aufgabe 6 – Eingabe ist leer
# **Beschreibung:**
# Frage so lange nach Eingabe, bis der Benutzer etwas schreibt.

# %%
text = ""
while __________________:
    text = input("Gib einen Text ein: ")

# %% [markdown]
# ### Aufgabe 7 – Solange Zahl negativ ist
# **Beschreibung:**
# Fordere so lange eine neue Zahl, bis sie positiv ist.

# %%
zahl = int(input("Gib eine Zahl ein: "))
while __________________:
    zahl = int(input("Bitte positive Zahl eingeben: "))

# %% [markdown]
# ### Aufgabe 8 – Uhrzeit eingeben
# **Beschreibung:**
# Nur Uhrzeiten zwischen 0 und 23 sind erlaubt.

# %%
uhrzeit = int(input("Gib eine Uhrzeit (0–23) ein: "))
while __________________:
    print("Ungültig.")
    uhrzeit = int(input("Gib eine gültige Uhrzeit ein: "))

# %% [markdown]
# ### Aufgabe 9 – Solange falsche Antwort
# **Beschreibung:**
# Frage nach der Hauptstadt von Frankreich, bis die richtige Antwort kommt.

# %%
antwort = ""
while __________________:
    antwort = input("Was ist die Hauptstadt von Frankreich? ")

# %% [markdown]
# ### Aufgabe 10 – Menü: Nur bei Auswahl „Beenden“ stoppen
# **Beschreibung:**
# Wiederhole das Menü, bis der Benutzer 'Beenden' eingibt.

# %%
wahl = ""
while __________________:
    print("1) Spiel starten\n2) Einstellungen\n3) Beenden")
    wahl = input("Auswahl: ")
