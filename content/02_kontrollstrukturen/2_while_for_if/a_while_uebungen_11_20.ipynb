# %% [markdown]
# ### Aufgabe 11 – PIN-Abfrage (max. 3 Versuche)
# **Beschreibung:**
# Erlaube die Eingabe eines PIN-Codes. Maximal 3 Versuche sind erlaubt.

# %%
versuche = 0
pin = ""
while __________________:
    pin = input("PIN eingeben: ")
    versuche = versuche + 1

# %% [markdown]
# ### Aufgabe 12 – Rechenspiel
# **Beschreibung:**
# Frage so lange 'Wie viel ist 3 + 4?', bis die richtige Antwort kommt.

# %%
antwort = ""
while __________________:
    antwort = input("Wie viel ist 3 + 4? ")

# %% [markdown]
# ### Aufgabe 13 – Eingabe: Nur Zahlen zwischen 1 und 10
# **Beschreibung:**
# Frage so lange eine Zahl ab, bis eine Zahl zwischen 1 und 10 eingegeben wird.

# %%
zahl = int(input("Zahl zwischen 1 und 10: "))
while __________________:
    print("Ungültig.")
    zahl = int(input("Bitte erneut eingeben: "))

# %% [markdown]
# ### Aufgabe 14 – String darf nicht „Ende“ sein
# **Beschreibung:**
# Wiederhole die Eingabe, solange der Benutzer nicht 'Ende' schreibt.

# %%
eingabe = ""
while __________________:
    eingabe = input("Eingabe (Ende zum Stoppen): ")

# %% [markdown]
# ### Aufgabe 15 – Schleife zählt nur bei geraden Zahlen
# **Beschreibung:**
# Zähle in Zweierschritten nach oben, solange die Zahl kleiner als 10 ist.

# %%
x = int(input("Startwert: "))
while __________________:
    print(x)
    x = x + 2

# %% [markdown]
# ### Aufgabe 16 – Temperaturüberwachung
# **Beschreibung:**
# Fordere neue Temperaturwerte, solange die Temperatur über 30 °C liegt.

# %%
temp = float(input("Temperatur in °C: "))
while __________________:
    print("Zu heiß!")
    temp = float(input("Neue Temperatur: "))

# %% [markdown]
# ### Aufgabe 17 – Nur solange Eingabe ein Buchstabe ist
# **Beschreibung:**
# Frage Zeichen ab, solange die Eingabe nur aus einem Buchstaben besteht.

# %%
zeichen = input("Gib ein Zeichen ein: ")
while __________________:
    print("Danke.")
    zeichen = input("Nächstes Zeichen: ")

# %% [markdown]
# ### Aufgabe 18 – Nur bei bestimmten Benutzernamen
# **Beschreibung:**
# Erlaube nur Zugriff für den Benutzer 'admin'.

# %%
benutzer = input("Benutzername: ")
while __________________:
    print("Zugriff verweigert.")
    benutzer = input("Benutzername: ")

# %% [markdown]
# ### Aufgabe 19 – Passwort und Benutzer
# **Beschreibung:**
# Frage Benutzername und Passwort ab, solange sie leer sind.

# %%
user = ""
pw = ""
while __________________:
    user = input("Benutzername: ")
    pw = input("Passwort: ")

# %% [markdown]
# ### Aufgabe 20 – Zahl muss größer als 100 sein
# **Beschreibung:**
# Fordere neue Zahlen, solange sie kleiner oder gleich 100 sind.

# %%
x = int(input("Zahl: "))
while __________________:
    print("Zahl zu klein.")
    x = int(input("Zahl: "))
