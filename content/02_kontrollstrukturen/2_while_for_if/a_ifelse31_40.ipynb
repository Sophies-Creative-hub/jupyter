# %% [markdown]
# ### Aufgabe 31: Lücke füllen
# Kombiniere Vor- und Nachname.

# %%
vorname = input("Vorname: ")
nachname = input("Nachname: ")
# Ergänze hier:
print("Dein Name ist", __________)

# %%
# Test
assert isinstance(vorname, str) and isinstance(nachname, str), "Beides sollte ein String sein"
print("✅ Test bestanden")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-8d4b12498895> in <cell line: 0>()
#       1 # Test
# ----> 2 assert isinstance(vorname, str) and isinstance(nachname, str), "Beides sollte ein String sein"
#       3 print("✅ Test bestanden")
#
# NameError: name 'vorname' is not defined

# %% [markdown]
# ### Aufgabe 32: Code vervollständigen
# Zahl liegt zwischen 10 und 20.

# %%
zahl = int(input("Gib eine Zahl ein: "))

# Ergänze hier:
if zahl >= 10 and __________:
    print("Die Zahl liegt zwischen 10 und 20.")
else:
    print("Die Zahl liegt außerhalb des Bereichs.")

# %%
# Test
assert isinstance(zahl, int), "Zahl sollte eine Ganzzahl sein"
print("✅ Test bestanden")

# %% [markdown]
# ### Aufgabe 33: Code reparieren
# Preis mit Rabatt berechnen.

# %%
preis = input("Preis: ")
rabatt = input("Rabatt in %: ")

endpreis = preis - (preis * rabatt / 100)
print("Endpreis:", endpreis)
# Out:
# Preis: 10.5
# Rabatt in %: 2.5
# Endpreis: 10.2375

# %%
# Test
preis = float(preis)
rabatt = float(rabatt)
endpreis = preis - (preis * rabatt / 100)
assert isinstance(endpreis, float), "Endpreis sollte ein Float sein"
print("✅ Test bestanden")

# %% [markdown]
# ### Aufgabe 34: Code selbst schreiben
# Celsius in Fahrenheit umrechnen.

# %%
# Schreibe deinen Code hier

# %%
# Test
assert isinstance(celsius, float), "Celsius sollte ein Float sein"
assert isinstance(fahrenheit, float), "Fahrenheit sollte ein Float sein"
print("✅ Test bestanden")

# %% [markdown]
# ### Aufgabe 35: Lücke füllen
# Langes oder kurzes Wort.

# %%
wort = input("Gib ein Wort ein: ")

if len(wort) > 8:
    print("Langes Wort")
else:
    print(_______)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-87a5d38585a2> in <cell line: 0>()
# ----> 1 wort = input("Gib ein Wort ein: ")
#       2
#       3 if len(wort) > 8:
#       4     print("Langes Wort")
#       5 else:
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# ...

# %%
# Test
assert isinstance(wort, str), "Wort sollte ein String sein"
print("✅ Test bestanden")

# %% [markdown]
# ### Aufgabe 36: Zeile ergänzen
# Geburtsjahr berechnen.

# %%
alter = int(input("Wie alt bist du? "))
jahr = 2025
# Ergänze hier:
geburtsjahr = _______________________
print("Du wurdest geboren im Jahr", geburtsjahr)

# %%
# Test
geburtsjahr = jahr - alter
assert isinstance(geburtsjahr, int), "Geburtsjahr sollte ein Integer sein"
print("✅ Test bestanden")

# %% [markdown]
# ### Aufgabe 37: Code reparieren
# Zahl analysieren: negativ, null, positiv.

# %%
x = float(input("Zahl: "))

if x = 0:
    print("Null")
elif x < 0:
    print("Negativ")
else:
    print("Positiv")

# %%
# Test
assert isinstance(x, float), "x sollte ein Float sein"
print("✅ Test bestanden")

# %% [markdown]
# ### Aufgabe 38: Code selbst schreiben
# Passwort prüfen.

# %%
# Schreibe deinen Code hier

# %%
# Test
assert isinstance(passwort, str), "Passwort sollte ein String sein"
print("✅ Test bestanden")

# %% [markdown]
# ### Aufgabe 39: Lücke füllen
# Summe ist gerade oder ungerade.

# %%
a = int(input("Zahl 1: "))
b = int(input("Zahl 2: "))

if (a + b) % 2 == 0:
    print("Summe ist gerade.")
else:
    print("__________")

# %%
# Test
assert isinstance(a, int) and isinstance(b, int), "Beide Zahlen sollten Integer sein"
print("✅ Test bestanden")

# %% [markdown]
# ### Aufgabe 40: Mini-Projekt
# Energielevel bewerten.

# %%
# Schreibe deinen Code hier

# %%
# Test
assert isinstance(energie, int), "Energie sollte eine Ganzzahl sein"
print("✅ Test bestanden")
