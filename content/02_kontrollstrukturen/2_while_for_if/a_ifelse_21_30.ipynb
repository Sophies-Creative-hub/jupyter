# %% [markdown]
# ### Aufgabe 21: Code reparieren
# Login mit Benutzernamen und Passwort.

# %%
benutzer = input("Benutzername: ")
passwort = input("Passwort: ")

if benutzer == "admin" and passwort = "1234":
    print("Login erfolgreich")
else:
    print("Zugang verweigert")  # Repariere den Vergleichsoperator

# %% [markdown]
# ### Aufgabe 22: Code vervollständigen
# Dreieck prüfen.

# %%
a = int(input("Seite A: "))
b = int(input("Seite B: "))
c = int(input("Seite C: "))

if a + b > c and a + c > b and b + c > a:
    print("Dreieck möglich")
else:
    # Ergänze hier

# %% [markdown]
# ### Aufgabe 23: Lücke füllen
# Gerade oder ungerade Zahl.

# %%
zahl = int(input("Zahl: "))

if _________:
    print("Gerade Zahl")
else:
    print("Ungerade Zahl")

# %% [markdown]
# ### Aufgabe 24: Code selbst schreiben
# Größte von drei Zahlen finden.

# %%
# Schreibe deinen Code hier

# %% [markdown]
# ### Aufgabe 25: Code reparieren
# Benutzereingabe prüfen.

# %%
wahl = input("Tee oder Kaffee? ")

if wahl == tee:
    print("Gute Wahl!")
else:
    print("Auch lecker!")  # Füge Anführungszeichen hinzu

# %% [markdown]
# ### Aufgabe 26: Zeile ergänzen
# Altersgruppe bestimmen.

# %%
alter = int(input("Alter: "))

if alter < 13:
    gruppe = "Kind"
elif alter < 18:
    gruppe = "Jugendlicher"
# Ergänze hier:
print("Du bist ein", gruppe)

# %% [markdown]
# ### Aufgabe 27: Lücke füllen
# Rabattberechnung für Studierende.

# %%
preis = float(input("Produktpreis: "))
student = input("Bist du Student/in? (ja/nein): ") == "ja"

if student:
    rabatt = _________
else:
    rabatt = 0

print("Endpreis:", preis - rabatt)

# %% [markdown]
# ### Aufgabe 28: Code selbst schreiben
# Namen auf Anfangsbuchstaben prüfen.

# %%
# Schreibe deinen Code hier

# %% [markdown]
# ### Aufgabe 29: Code vervollständigen
# Temperaturbereich prüfen.

# %%
temp = float(input("Temperatur: "))

if temp < 0:
    print("Gefroren")
elif temp >= 0 and temp <= 30:
    print("Normal")
else:
    # Ergänze hier

# %% [markdown]
# ### Aufgabe 30: Mini-Quiz schreiben
# Einfache Rechenfrage stellen und überprüfen.

# %%
# Schreibe deinen Code hier
