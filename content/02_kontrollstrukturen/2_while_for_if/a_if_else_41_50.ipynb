# %% [markdown]
# ### Aufgabe 41: Code ergänzen
# Berechne das Gehalt anhand von Stunden und Lohnsatz.

# %%
stunden = float(input("Wie viele Stunden hast du gearbeitet? "))
lohnsatz = float(input("Lohn pro Stunde: "))

# Ergänze hier:
gehalt = ___________________________
print("Du verdienst", gehalt, "Euro.")

# %% [markdown]
# ### Aufgabe 42: Lücke füllen
# Zwei Zahlen vergleichen und Differenz anzeigen.

# %%
x = int(input("Zahl 1: "))
y = int(input("Zahl 2: "))

if x > y:
    print("Differenz:", x - y)
elif x < y:
    print("Differenz:", y - x)
else:
    print("__________")

# %% [markdown]
# ### Aufgabe 43: Code reparieren
# Einfacher Alterscheck.

# %%
alter = int(input("Wie alt bist du? "))

if alter < 18:
    print("Minderjährig")
if alter >= 18:
    print("Volljährig")
else:
    print("Ungültig")

# %% [markdown]
# ### Aufgabe 44: Code selbst schreiben
# Preisvergleich zweier Produkte.

# %%
# Schreibe deinen Code hier

# %% [markdown]
# ### Aufgabe 45: Zeile ergänzen
# Temperaturbereiche ausgeben.

# %%
temp = float(input("Temperatur in °C: "))

if temp < 0:
    print("Gefroren")
elif temp <= 15:
    print("Kalt")
elif __________:
    print("Angenehm")
else:
    print("Heiß")

# %% [markdown]
# ### Aufgabe 46: Code vervollständigen
# Prozentanteil berechnen.

# %%
wert = float(input("Wert: "))
prozent = float(input("Prozentsatz: "))

# Ergänze die Berechnung:
anteil = ________________________

print("Anteil ist:", anteil)

# %% [markdown]
# ### Aufgabe 47: Code reparieren
# Sonderpreis bei bestimmten Bedingungen.

# %%
preis = float(input("Preis: "))

if preis < 10 or preis > 100:
print("Sonderpreis")

# %% [markdown]
# ### Aufgabe 48: Lücke füllen
# Passwortlänge überprüfen.

# %%
pw = input("Passwort: ")

if len(pw) > 6:
    print("Gültiges Passwort")
else:
    print("__________")

# %% [markdown]
# ### Aufgabe 49: Code selbst schreiben
# Taschenrechner mit +, -, * und /

# %%
# Schreibe deinen Code hier

# %% [markdown]
# ### Aufgabe 50: Mini-Quiz
# Multiple Choice Frage programmieren.

# %%
# Schreibe deinen Code hier
