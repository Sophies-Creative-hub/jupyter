# %% [markdown]
# ### Aufgabe 51: Verschachtelte Bedingungen
# Eintritt ab 16 Jahren und mit Ticket.

# %%
ticket = input("Hast du ein Ticket? (ja/nein): ")
alter = int(input("Wie alt bist du? "))

# Ergänze die Bedingung:
# Wenn ticket == "ja" und alter >= 16 → Eintritt erlaubt
# Sonst → Kein Zutritt

# %% [markdown]
# ### Aufgabe 52: Umgekehrte Bereichsprüfung
# Zahlen außerhalb des Bereichs 10–20 sind zugelassen.

# %%
zahl = int(input("Gib eine Zahl ein: "))

# Wenn zahl NICHT zwischen 10 und 20 liegt → "Zugelassen"
# Sonst → "Nicht erlaubt"

# %% [markdown]
# ### Aufgabe 53: ODER-Verknüpfung
# Rabatt für Stammkunden oder hohe Beträge.

# %%
kunde = input("Bist du Stammkunde? (ja/nein): ")
betrag = float(input("Bestellwert in Euro: "))

# Wenn Stammkunde ODER Betrag > 100 → Rabatt gewähren

# %% [markdown]
# ### Aufgabe 54: Groß- und Kleinschreibung
# JA, Ja, ja sollen alle akzeptiert werden.

# %%
antwort = input("Willst du fortfahren? (ja/nein): ")

# Zähle alle Varianten von "ja" als Zustimmung

# %% [markdown]
# ### Aufgabe 55: Gültige Kombination
# Nur blau + Hund ergibt perfekte Kombination.

# %%
farbe = input("Lieblingsfarbe: ")
tier = input("Lieblingstier: ")

# Wenn Farbe == "blau" UND Tier == "Hund" → Perfekte Kombination

# %% [markdown]
# ### Aufgabe 56: Zwei Bedingungen – doppelte Ablehnung
# Wenn beides nein ist → schlechtes Wetter?

# %%
sonne = input("Scheint die Sonne? (ja/nein): ")
regen = input("Regnet es? (ja/nein): ")

# Wenn beides "nein" → Schlechtes Wetter?

# %% [markdown]
# ### Aufgabe 57: Energielevel einstufen
# Bewerte die Energie von 1–10 in drei Stufen.

# %%
energie = int(input("Wie ist dein Energielevel (1–10)? "))

# 1–3: "Pause machen"
# 4–6: "Noch ein bisschen!"
# 7–10: "Volle Power!"

# %% [markdown]
# ### Aufgabe 58: Umgekehrte Passwortprüfung
# Nur wenn Passwort 'geheim' ist → Willkommen.

# %%
antwort = input("Kennwort: ")

# Wenn Antwort NICHT gleich "geheim" → "Zugang verweigert"
# Sonst → "Willkommen"

# %% [markdown]
# ### Aufgabe 59: Betrag aufrunden ohne Funktion
# Wenn Nachkommastellen → auf volle Zahl runden.

# %%
preis = float(input("Betrag: "))

# Wenn Nachkommastelle vorhanden → 1 dazuzählen und anzeigen

# %% [markdown]
# ### Aufgabe 60: Eingabe verneinen
# Antworte auf "Magst du Schokolade?"

# %%
antwort = input("Magst du Schokolade? (ja/nein): ")

# Wenn "nein" → "Oh schade!"
# Sonst → "Süß!"
