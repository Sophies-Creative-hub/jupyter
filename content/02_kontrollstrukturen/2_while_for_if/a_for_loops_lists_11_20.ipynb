# %% [markdown]
# ### Aufgabe 11: Lücke füllen
# Eintritt nur mit Ticket und Ausweis.

# %%
ticket = input("Hast du ein Ticket? (ja/nein): ") == "ja"
ausweis = input("Hast du einen Ausweis? (ja/nein): ") == "ja"

if ________ and ________:
    print("Eintritt erlaubt.")
else:
    print("Kein Zutritt.")

# %% [markdown]
# ### Aufgabe 12: Code vervollständigen
# Zahl in Text umwandeln. Für Zahlen 1 bis 10.
#
# Für Extra Herausforderung: 0 bis 100.

# %%
zahl = 3
# Ergänze hier:

# %% [markdown]
# ### Aufgabe 13: Code reparieren
# Rechnung korrigieren.

# %%
x = 10
y = 5
ergebnis = x - y * 2
print("Ergebnis ist", ergebnis)  # Überprüfe den Rechenausdruck

# %% [markdown]
# ### Aufgabe 14: Code selbst schreiben
# Ist eine Zahl durch eine andere ohne Rest teilbar?

# %%
# Schreibe deinen Code hier

# %% [markdown]
# ### Aufgabe 15: Lücke füllen
# Note je nach Punktzahl.

# %%
punkte = int(input("Wie viele Punkte? "))

if punkte >= 90:
    print("Note: Sehr gut")
elif punkte >= 75:
    print("Note: Gut")
elif punkte >= 60:
    print("Note: Befriedigend")
else:
    print("Note: __________")

# %% [markdown]
# ### Aufgabe 16: Zeile ergänzen
# Länge eines Wortes ausgeben.

# %%
wort = input("Gib ein Wort ein: ")
# Ergänze hier:

# %% [markdown]
# ### Aufgabe 17: Code reparieren
# BMI richtig berechnen.

# %%
gewicht = input("Gewicht in kg: ")
groesse = input("Größe in m: ")
# Berechne den BMI korrekt

# %% [markdown]
# ### Aufgabe 18: Code selbst schreiben
# Grüße je nach Uhrzeit.

# %%
# Schreibe deinen Code hier

# %% [markdown]
# ### Aufgabe 19: Code vervollständigen
# Taschenrechner-Ausgabe ergänzen.

# %%
a = float(input("Erste Zahl: "))
b = float(input("Zweite Zahl: "))
print("Summe:", a + b)
print("Differenz:", __________)
print("Produkt:", a * b)

# %% [markdown]
# ### Aufgabe 20: Lücken füllen
# Eintrittspreis je nach Alter.

# %%
alter = ______(input("Alter: "))

if alter < 6:
    ______ = 0
elif alter <= 18:
    ______ = 5
else:
    preis = _______

print("Eintrittspreis:", preis, "Euro")
