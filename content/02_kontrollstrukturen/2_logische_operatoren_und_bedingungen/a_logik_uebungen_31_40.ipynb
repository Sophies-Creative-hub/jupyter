# %% [markdown]
# ### Aufgabe 31 – Bürozugang
# **Beschreibung:**
# Ein Mitarbeiterausweis ist notwendig. Zugang wird aber auch gewährt, wenn der Benutzername 'chef' lautet. Zudem darf die Uhrzeit nicht außerhalb der Bürozeiten (vor 8 oder nach 18 Uhr) liegen.

# %%
ausweis = input("Hast du einen Ausweis? (ja/nein): ")
benutzer = input("Benutzername: ")
stunde = int(input("Uhrzeit (0–23): "))

if ________________________:
    print("Zugang erlaubt.")
else:
    print("Zugang verweigert.")

# %% [markdown]
# ### Aufgabe 32 – Kommentarfilter
# **Beschreibung:**
# Ein Kommentar ist gültig, wenn er nicht leer ist, nicht nur aus Leerzeichen besteht und nicht das Wort 'Spam' enthält.

# %%
kommentar = input("Kommentar: ")

if ________________________:
    print("Kommentar akzeptiert.")
else:
    print("Kommentar ungültig.")

# %% [markdown]
# ### Aufgabe 33 – Spezielle Einladung
# **Beschreibung:**
# Nur wer eingeladen wurde und entweder über 18 oder mit Begleitung kommt, darf eintreten.

# %%
eingeladen = input("Eingeladen? (ja/nein): ")
alter = int(input("Wie alt bist du? "))
begleitung = input("Begleitung dabei? (ja/nein): ")

if ________________________:
    print("Willkommen!")
else:
    print("Zutritt verweigert.")

# %% [markdown]
# ### Aufgabe 34 – Prüfungsversuch
# **Beschreibung:**
# Eine Prüfung darf nur wiederholt werden, wenn sie nicht bestanden wurde oder wenn sie zwar bestanden, aber mit weniger als 60 Punkten war.

# %%
status = input("Bestanden? (ja/nein): ")
punkte = int(input("Punktezahl: "))

if ________________________:
    print("Wiederholung erlaubt.")
else:
    print("Keine Wiederholung nötig.")

# %% [markdown]
# ### Aufgabe 35 – Rabatt kombinieren
# **Beschreibung:**
# Ein Kunde bekommt nur Rabatt, wenn er Mitglied ist und entweder den Gutscheincode eingibt oder der Warenwert mindestens 200 € beträgt.

# %%
mitglied = input("Mitglied? (ja/nein): ")
gutschein = input("Gutscheincode vorhanden? (ja/nein): ")
wert = float(input("Warenwert in €: "))

if ________________________:
    print("Rabatt gewährt.")
else:
    print("Kein Rabatt.")

# %% [markdown]
# ### Aufgabe 36 – Passwortanalyse
# **Beschreibung:**
# Ein Passwort gilt als unsicher, wenn es entweder '123456' oder 'passwort' entspricht oder kürzer als 6 Zeichen ist.

# %%
pw = input("Neues Passwort: ")

if ________________________:
    print("Passwort akzeptiert.")
else:
    print("Passwort unsicher.")

# %% [markdown]
# ### Aufgabe 37 – Öffnungszeiten + Wochentag
# **Beschreibung:**
# Ein Laden hat geöffnet, wenn er nicht am Sonntag ist und wenn die Uhrzeit zwischen 9 und 19 liegt.

# %%
tag = input("Wochentag: ")
uhrzeit = int(input("Uhrzeit (0–23): "))

if ________________________:
    print("Laden geöffnet.")
else:
    print("Laden geschlossen.")

# %% [markdown]
# ### Aufgabe 38 – Sprachwahl und Sondermodus
# **Beschreibung:**
# Wenn der Benutzer 'admin' ist und entweder Debug-Modus aktiv ist oder 'root' als Rolle angegeben ist, gib 'Expertenzugang' aus.

# %%
benutzer = input("Benutzername: ")
rolle = input("Rolle: ")
debug = input("Debug-Modus aktiv? (ja/nein): ")

if ________________________:
    print("Expertenzugang.")
else:
    print("Standardzugang.")

# %% [markdown]
# ### Aufgabe 39 – Gültige Bewertung
# **Beschreibung:**
# Ein Bewertungseintrag ist nur gültig, wenn der Kommentar nicht leer ist und die Bewertungspunktzahl zwischen 1 und 5 liegt, oder wenn nur die Punktzahl angegeben wurde.

# %%
kommentar = input("Kommentar: ")
bewertung = int(input("Bewertung (1–5): "))

if ________________________:
    print("Bewertung gültig.")
else:
    print("Ungültige Bewertung.")

# %% [markdown]
# ### Aufgabe 40 – Zugriff per VIP oder Login
# **Beschreibung:**
# Zugriff wird gewährt, wenn jemand als 'VIP' eingestuft ist, oder wenn Benutzername und Passwort beide nicht leer sind.

# %%
status = input("Status (normal/VIP): ")
user = input("Benutzername: ")
pw = input("Passwort: ")

if ________________________:
    print("Zugriff erlaubt.")
else:
    print("Zugriff verweigert.")
