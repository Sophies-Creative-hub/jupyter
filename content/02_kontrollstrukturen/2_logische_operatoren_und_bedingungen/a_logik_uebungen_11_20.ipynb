# %% [markdown]
# ### Aufgabe 11 – Türöffnung
# TODO: Nur wenn Passwort == 'offen' und Raum == '42', dann Tür öffnen.

# %%
pw = input("Passwort: ")
raum = input("Raumnummer: ")

if ________________________:
    print("Tür öffnet sich.")
else:
    print("Zugriff verweigert.")

# %% [markdown]
# ### Aufgabe 12 – Haustierprüfung
# TODO: Wenn Tier == 'Hund', 'Katze' oder 'Hamster', dann erlaubt.

# %%
tier = input("Welches Haustier möchtest du? ")

if ________________________:
    print("Haustier erlaubt.")
else:
    print("Nicht erlaubt.")

# %% [markdown]
# ### Aufgabe 13 – Einkaufsrabatt
# TODO: Rabatt, wenn Mitglied == 'ja' oder Warenwert > 100.

# %%
mitglied = input("Mitglied? (ja/nein): ")
wert = float(input("Warenwert: "))

if ________________________:
    print("Rabatt aktiviert!")
else:
    print("Kein Rabatt.")

# %% [markdown]
# ### Aufgabe 14 – Mittagsspecial
# TODO: Nur wenn Montag und Uhrzeit zwischen 12–14 Uhr → Gratiskaffee.

# %%
tag = input("Wochentag: ")
stunde = int(input("Stunde (0–23): "))

if ________________________:
    print("Gratiskaffee verfügbar!")
else:
    print("Kein Gratiskaffee.")

# %% [markdown]
# ### Aufgabe 15 – Login prüfen
# TODO: Passwort darf NICHT leer und NICHT kürzer als 4 Zeichen sein.

# %%
pw = input("Passwort: ")

if ________________________:
    print("Passwort gültig.")
else:
    print("Passwort ungültig.")

# %% [markdown]
# ### Aufgabe 16 – Fitnesscheck
# TODO: Wenn BMI < 25 und Alter < 40 → sporttauglich.

# %%
bmi = float(input("BMI: "))
alter = int(input("Alter: "))

if ________________________:
    print("Sporttauglich.")
else:
    print("Nicht sporttauglich.")

# %% [markdown]
# ### Aufgabe 17 – Zahlensperre
# TODO: Nur Zahlen zwischen 0 und 100 erlaubt.

# %%
x = int(input("Zahl: "))

if ________________________:
    print("Zulässig.")
else:
    print("Ungültige Eingabe.")

# %% [markdown]
# ### Aufgabe 18 – Smart Home
# TODO: Wenn Bewegung == 'ja' und Uhrzeit >= 20 → Licht an.

# %%
bewegung = input("Bewegung erkannt? (ja/nein): ")
uhrzeit = int(input("Uhrzeit (0–23): "))

if ________________________:
    print("Licht wird eingeschaltet.")
else:
    print("Licht bleibt aus.")

# %% [markdown]
# ### Aufgabe 19 – Mailprüfung
# TODO: E-Mail muss '@' enthalten und darf nicht leer sein.

# %%
mail = input("E-Mail-Adresse: ")

if ________________________:
    print("E-Mail gültig.")
else:
    print("E-Mail ungültig.")

# %% [markdown]
# ### Aufgabe 20 – Altersgruppe
# TODO: Gib 'Kind', 'Teenager' oder 'Erwachsen' je nach Alter aus.

# %%
alter = int(input("Alter: "))

if ________________________:
    print("Du bist ein Kind.")
elif ________________________:
    print("Du bist ein Teenager.")
else:
    print("Du bist erwachsen.")
