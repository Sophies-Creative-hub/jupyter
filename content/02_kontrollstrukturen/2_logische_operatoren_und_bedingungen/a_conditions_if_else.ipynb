# %% [markdown]
# ## Aufgabe 1: Einfache if-Bedingung

# %% [markdown]
# Ergänze die fehlenden Zeichen, sodass der Code prüft, ob `x` größer als 5 ist.

# %%
x = 10
if x ____ 5:
    print("x ist größer als 5")  # Erwartete Ausgabe: x ist größer als 5

# %% [markdown]
# ## Aufgabe 2: else-Bedingung

# %% [markdown]
# Ergänze den Code, sodass die `else`-Bedingung ausgeführt wird.

# %%
y = 3
if y > 5:
    print("y ist groß")
____:
    print("y ist klein")  # Erwartete Ausgabe: y ist klein

# %% [markdown]
# ## Aufgabe 3: Positive oder negative Zahl

# %% [markdown]
# Ergänze den Code, sodass eine Zahl als **positiv oder negativ** klassifiziert wird.

# %%
zahl = -4
if zahl ____ 0:
    print("Die Zahl ist positiv")
else:
    print("Die Zahl ist negativ")  # Erwartete Ausgabe: Die Zahl ist negativ

# %% [markdown]
# ## Aufgabe 4: Zahl ist Null

# %% [markdown]
# Ergänze den Code, um zu prüfen, ob eine Zahl genau `0` ist.

# %%
zahl = 0
if zahl ____ 0:
    print("Die Zahl ist null")  # Erwartete Ausgabe: Die Zahl ist null
else:
    print("Die Zahl ist nicht null")

# %% [markdown]
# ## Aufgabe 5: Gerade oder ungerade Zahl

# %% [markdown]
# Ergänze den Code, um zu prüfen, ob eine Zahl durch `2` teilbar ist.

# %%
x = 8
if x ____ 2 == 0:
    print("Die Zahl ist gerade")  # Erwartete Ausgabe: Die Zahl ist gerade
else:
    print("Die Zahl ist ungerade")

# %% [markdown]
# ## Aufgabe 6: if-elif-else

# %% [markdown]
# Ergänze den Code, sodass `elif` eine zusätzliche Bedingung überprüft.

# %%
z = 10
if z < 5:
    print("z ist klein")
____ z == 10:
    print("z ist genau 10")  # Erwartete Ausgabe: z ist genau 10
else:
    print("z ist größer als 10")

# %% [markdown]
# ## Aufgabe 7: Temperaturklassifikation

# %% [markdown]
# Ergänze den Code, sodass Temperaturen als **kalt, angenehm oder heiß** klassifiziert werden.

# %%
temperatur = 22
if temperatur < 10:
    print("Es ist kalt")
____ temperatur < 25:
    print("Es ist angenehm")  # Erwartete Ausgabe: Es ist angenehm
else:
    print("Es ist heiß")

# %% [markdown]
# ## Aufgabe 8: Notenklassifikation

# %% [markdown]
# Ergänze den Code, sodass eine Note klassifiziert wird.

# %%
note = 85
if note >= 90:
    print("Sehr gut")
____ note >= 75:
    print("Gut")  # Erwartete Ausgabe: Gut
else:
    print("Bestanden")

# %% [markdown]
# ## Aufgabe 9: Bereichsprüfung

# %% [markdown]
# Ergänze den Code, um zu prüfen, ob eine Zahl zwischen `10` und `20` liegt.

# %%
x = 15
if 10 ____ x ____ 20:
    print("x liegt im Bereich")  # Erwartete Ausgabe: x liegt im Bereich

# %% [markdown]
# ## Aufgabe 10: Werte außerhalb eines Bereichs

# %% [markdown]
# Ergänze den Code, um zu prüfen, ob `a` entweder **kleiner als 5 oder größer als 15** ist.

# %%
a = 3
if a ____ 5 ____ a ____ 15:
    print("a liegt außerhalb des Bereichs")  # Erwartete Ausgabe: a liegt außerhalb des Bereichs

# %% [markdown]
# ## Aufgabe 11: and-Operator

# %% [markdown]
# Ergänze den Code, um zwei Bedingungen mit `and` zu kombinieren.

# %%
x = 6
y = 12
if x > 5 ____ y < 15:
    print("Beide Bedingungen sind erfüllt")  # Erwartete Ausgabe: Beide Bedingungen sind erfüllt

# %% [markdown]
# ## Aufgabe 12: or-Operator

# %% [markdown]
# Ergänze den Code, um zwei Bedingungen mit `or` zu kombinieren.

# %%
x = 4
y = 20
if x > 10 ____ y < 25:
    print("Mindestens eine Bedingung ist erfüllt")  # Erwartete Ausgabe: Mindestens eine Bedingung ist erfüllt

# %% [markdown]
# ## Aufgabe 13: not-Operator

# %% [markdown]
# Ergänze den Code, um eine Bedingung mit `not` umzudrehen.

# %%
wahrheit = False
if ____ wahrheit:
    print("Die Bedingung ist True")  # Erwartete Ausgabe: Die Bedingung ist True

# %% [markdown]
# ## Aufgabe 14: Prüfung auf None

# %% [markdown]
# Ergänze den Code, um zu prüfen, ob eine Variable nicht `None` ist.

# %%
wert = None
if ____ wert:
    print("Wert ist nicht None")
else:
    print("Wert ist None")  # Erwartete Ausgabe: Wert ist None

# %% [markdown]
# ## Aufgabe 15: Prüfung auf leere Liste

# %% [markdown]
# Ergänze den Code, um eine Liste auf **Leere** zu prüfen.

# %%
liste = []
if not ____:
    print("Die Liste ist leer")  # Erwartete Ausgabe: Die Liste ist leer

# %% [markdown]
# ## Aufgabe 16: Prüfung auf nicht leeren String

# %% [markdown]
# Ergänze den Code, um zu prüfen, ob ein String **nicht leer** ist.

# %%
text = "Hallo"
if ____ text:
    print("Der Text ist nicht leer")  # Erwartete Ausgabe: Der Text ist nicht leer

# %% [markdown]
# ## Aufgabe 17: Altersprüfung mit Benutzerinput

# %% [markdown]
# Ergänze den Code, um das Alter des Benutzers zu prüfen.

# %%
alter = int(input("Gib dein Alter ein: "))
if alter ____ 18:
    print("Du bist volljährig")
else:
    print("Du bist noch minderjährig")

# %% [markdown]
# ## Aufgabe 18: Namensüberprüfung

# %% [markdown]
# Ergänze den Code, um zu prüfen, ob ein eingegebener Name `Alice` ist.

# %%
name = input("Gib deinen Namen ein: ")
if name ____ "Alice":
    print("Hallo, Alice!")  # Erwartete Ausgabe: Hallo, Alice!
else:
    print("Du bist nicht Alice.")

# %% [markdown]
# ## Aufgabe 19: Passwortüberprüfung

# %% [markdown]
# Ergänze den Code, um ein Passwort zu überprüfen.

# %%
passwort = input("Gib dein Passwort ein: ")
if passwort ____ "geheim123":
    print("Zugang gewährt")  # Erwartete Ausgabe: Zugang gewährt
else:
    print("Zugang verweigert")

# %% [markdown]
# ## Aufgabe 20: Benutzerentscheidungen

# %% [markdown]
# Ergänze den Code, um zu überprüfen, ob der Benutzer `Ja` oder `Nein` eingegeben hat.

# %%
antwort = input("Möchtest du fortfahren? (Ja/Nein): ")
if antwort ____ "Ja":
    print("Du hast Ja gesagt.")  # Erwartete Ausgabe: Du hast Ja gesagt.
elif antwort ____ "Nein":
    print("Du hast Nein gesagt.")  # Erwartete Ausgabe: Du hast Nein gesagt.
else:
    print("Ungültige Eingabe.")
