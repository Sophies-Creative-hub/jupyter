# %% [markdown]
# ### Aufgabe 1 – Sicherheitskontrolle
# TODO: Nur wenn Ticket == 'ja' und Ausweis == 'ja', dann Zutritt gewähren.

# %%
ticket = input("Hast du ein Ticket? (ja/nein): ")
ausweis = input("Hast du einen Ausweis? (ja/nein): ")

if _____________________________:
    print("Zutritt gewährt.")
else:
    print("Zutritt verweigert.")

# %% [markdown]
# ### Aufgabe 2 – Bewerbungsprüfung
# TODO: Nur wenn Alter ≥ 18 und Motivationsschreiben == 'ja', dann Einladung ausgeben.

# %%
alter = int(input("Wie alt bist du? "))
motivation = input("Motivationsschreiben vorhanden? (ja/nein): ")

if _____________________________:
    print("Du wirst eingeladen.")
else:
    print("Bewerbung unvollständig.")

# %% [markdown]
# ### Aufgabe 3 – Codeknacker
# TODO: Wenn Code '42' oder 'XY99' ist, akzeptiere ihn.

# %%
code = input("Sicherheitscode: ")

if ____________________________:
    print("Code akzeptiert.")
else:
    print("Falscher Code.")

# %% [markdown]
# ### Aufgabe 4 – Login-System
# TODO: Nur wenn Passwort == 'abc123' und Antwort == 'Pizza', dann Login erfolgreich.

# %%
pw = input("Passwort: ")
antwort = input("Was ist dein Lieblingsessen? ")

if ___________________________:
    print("Login erfolgreich.")
else:
    print("Login fehlgeschlagen.")

# %% [markdown]
# ### Aufgabe 5 – Agentenfreigabe
# TODO: Wenn Agent == '007' und Passwort == 'geheim', dann Zugriff gewähren.

# %%
agent = input("Agentenkennung: ")
passwort = input("Passwort: ")

if ________________________:
    print("Willkommen, Agent.")
else:
    print("Zugriff verweigert.")

# %% [markdown]
# ### Aufgabe 6 – Wetterwarnung
# TODO: Wenn Temperatur < 10 oder > 30, dann Warnung ausgeben.

# %%
temp = float(input("Temperatur in °C: "))

if ________________________:
    print("Ungewöhnliches Wetter!")
else:
    print("Temperatur normal.")

# %% [markdown]
# ### Aufgabe 7 – Begrüßung
# TODO: Wenn Nachricht 'ok' oder 'in Ordnung' ist, dann mit 'Danke!' antworten.

# %%
nachricht = input("Nachricht: ")

if ________________________:
    print("Danke!")

# %% [markdown]
# ### Aufgabe 8 – Parkregel
# TODO: Wenn Sonntag oder Uhrzeit < 7 oder > 20 → Parken erlaubt.

# %%
tag = input("Wochentag: ")
uhrzeit = int(input("Uhrzeit (0–23): "))

if ________________________:
    print("Parken erlaubt.")
else:
    print("Parkverbot.")

# %% [markdown]
# ### Aufgabe 9 – Benutzereingabe prüfen
# TODO: Benutzername darf NICHT leer sein und NICHT 'admin' heißen.

# %%
benutzer = input("Benutzername: ")

if ________________________:
    print("Benutzer akzeptiert.")
else:
    print("Ungültiger Benutzername.")

# %% [markdown]
# ### Aufgabe 10 – Extrembereich
# TODO: Zahl ist ein Extremwert, wenn sie < 10 oder > 90 ist.

# %%
x = int(input("Zahl: "))

if ________________________:
    print("Extremwert erkannt.")
