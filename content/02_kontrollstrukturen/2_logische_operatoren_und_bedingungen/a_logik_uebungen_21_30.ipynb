# %% [markdown]
# ### Aufgabe 21 – ✏️ Lücke füllen
# TODO: Wenn die Eingabe eine Zahl zwischen 100 und 999 ist, soll 'Dreistellig' ausgegeben werden.

# %%
x = int(input("Gib eine Zahl ein: "))

if x >= 100 ______ x <= 999:
    print("Dreistellig")
else:
    print("Nicht dreistellig")

# %% [markdown]
# ### Aufgabe 22 – 🔧 Code reparieren
# TODO: Der Benutzer soll nur Zugriff bekommen, wenn Name != '' und Passwort != ''. Der aktuelle Code funktioniert nicht korrekt.

# %%
name = input("Benutzername: ")
pw = input("Passwort: ")

if name != "" or pw != "":
    print("Zugriff gewährt.")
else:
    print("Zugriff verweigert.")

# %% [markdown]
# ### Aufgabe 23 – 🧩 Zeile ergänzen
# TODO: Ergänze die Bedingung, dass ein Jahr ein Schaltjahr ist, wenn es durch 4 teilbar ist, aber nicht durch 100 – außer durch 400.

# %%
jahr = int(input("Jahr: "))

# Ergänze hier:
if __________________________________________:
    print("Schaltjahr")
else:
    print("Kein Schaltjahr")

# %% [markdown]
# ### Aufgabe 24 – ✍️ Code vervollständigen
# TODO: Wenn Passwort länger als 6 Zeichen ist und mindestens ein '@' enthält, ist es gültig.

# %%
pw = input("Passwort: ")

if _________________________________________:
    print("Passwort gültig")
else:
    print("Passwort zu schwach")

# %% [markdown]
# ### Aufgabe 25 – 💡 Code von Grund auf schreiben
# TODO: Erstelle ein Programm, das das Alter und die Impfbereitschaft abfragt. Nur wenn Alter > 60 oder chronische Krankheit == 'ja' und Zustimmung == 'ja' → Impfung empfohlen.

# %%
# Dein Code hier

# %% [markdown]
# ### Aufgabe 26 – ✏️ Lücke füllen
# TODO: Wenn Name NICHT leer ist UND NICHT gleich 'Gast', begrüße mit 'Willkommen!'

# %%
name = input("Dein Name: ")

if not name == "" ______ not name == "Gast":
    print("Willkommen!")
else:
    print("Hallo Gast")

# %% [markdown]
# ### Aufgabe 27 – 🔧 Code reparieren
# TODO: Der Code soll erkennen, ob Benutzer 'admin' oder 'root' ist UND ein Passwort eingegeben wurde.

# %%
user = input("Benutzer: ")
pw = input("Passwort: ")

if user == "admin" or "root" and pw != "":
    print("Zugriff erlaubt")

# %% [markdown]
# ### Aufgabe 28 – 🧩 Zeile ergänzen
# TODO: Nur gültig, wenn der Wert zwischen 0 und 1 liegt ODER genau 100 ist.

# %%
wert = float(input("Wert eingeben: "))

# Ergänze hier:
if _______________________________________:
    print("Wert gültig")
else:
    print("Ungültiger Wert")

# %% [markdown]
# ### Aufgabe 29 – ✍️ Code vervollständigen
# TODO: Programm soll prüfen, ob Passwort NICHT '123456' oder 'passwort' ist UND mindestens 6 Zeichen hat.

# %%
pw = input("Neues Passwort: ")

if ________________________________________:
    print("Passwort akzeptiert")
else:
    print("Passwort unsicher")

# %% [markdown]
# ### Aufgabe 30 – 💡 Code Review verbessern
# TODO: Verbessere den Code so, dass NUR dann 'Eingabe erhalten' ausgegeben wird, wenn beide Felder ausgefüllt sind.

# %%
# Ursprünglicher Code:
user = input("Benutzername: ")
pw = input("Passwort: ")

if user != "" or pw != "":
    print("Eingabe erhalten")
else:
    print("Eingabe fehlt")
