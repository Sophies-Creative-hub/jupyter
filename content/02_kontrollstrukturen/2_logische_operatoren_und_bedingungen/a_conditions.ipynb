# %% [markdown]
# ## Aufgabe 1: Einfache Bedingung

# %% [markdown]
# Ergänze die Bedingung, sodass `x` nur ausgegeben wird, wenn es **positiv** ist.

# %%
x = 10
if ____:
    print("x ist positiv")  # Erwartete Ausgabe: x ist positiv

# %% [markdown]
# ## Aufgabe 2: Negative oder Null prüfen

# %% [markdown]
# Ergänze die Bedingung, sodass überprüft wird, ob `y` **negativ oder null** ist.

# %%
y = -3
if ____:
    print("y ist negativ oder null")  # Erwartete Ausgabe: y ist negativ oder null

# %% [markdown]
# ## Aufgabe 3: Zahlenbereich prüfen

# %% [markdown]
# Ergänze die Bedingung, sodass nur Zahlen zwischen `10` und `20` ausgegeben werden.

# %%
zahl = 15
if ____:
    print("Die Zahl liegt im Bereich")  # Erwartete Ausgabe: Die Zahl liegt im Bereich

# %% [markdown]
# ## Aufgabe 4: Gerade und größer als 10

# %% [markdown]
# Ergänze die Bedingung, sodass eine Zahl **gerade und größer als 10** sein muss.

# %%
num = 14
if ____:
    print("Die Zahl ist gerade und größer als 10")  # Erwartete Ausgabe: Die Zahl ist gerade und größer als 10

# %% [markdown]
# ## Aufgabe 5: Admin oder Moderator prüfen

# %% [markdown]
# Ergänze die Bedingung, sodass ein Benutzer nur Zugang hat, wenn er ein **Admin oder Moderator** ist.

# %%
rolle = "Admin"
if ____:
    print("Zugang gewährt")  # Erwartete Ausgabe: Zugang gewährt

# %% [markdown]
# ## Aufgabe 6: Temperaturklassifikation

# %% [markdown]
# Ergänze die Bedingung, sodass nur Temperaturen zwischen `15` und `25` als **angenehm** ausgegeben werden.

# %%
temperatur = 20
if ____:
    print("Angenehme Temperatur")  # Erwartete Ausgabe: Angenehme Temperatur

# %% [markdown]
# ## Aufgabe 7: Verschachtelte Altersprüfung

# %% [markdown]
# Ergänze die Bedingungen, sodass das richtige Altersniveau ausgegeben wird.

# %%
alter = 16
if ____:
    if ____:
        print("Du bist ein Kind")
    else:
        print("Du bist ein Jugendlicher")  # Erwartete Ausgabe: Du bist ein Jugendlicher
else:
    print("Du bist erwachsen")

# %% [markdown]
# ## Aufgabe 8: Verschachtelte gerade und positiv

# %% [markdown]
# Ergänze die Bedingungen, sodass eine Zahl nur dann als **gerade und positiv** ausgegeben wird.

# %%
zahl = 8
if ____:
    if ____:
        print("Die Zahl ist positiv und gerade")  # Erwartete Ausgabe: Die Zahl ist positiv und gerade

# %% [markdown]
# ## Aufgabe 9: Notenvalidierung

# %% [markdown]
# Ergänze die Bedingungen, sodass **nur gültige Noten** von `0 bis 100` akzeptiert werden.

# %%
note = 85
if ____:
    if ____:
        print("Gültige Note")  # Erwartete Ausgabe: Gültige Note
    else:
        print("Ungültige Note")

# %% [markdown]
# ## Aufgabe 10: Beide Zahlen positiv oder negativ

# %% [markdown]
# Ergänze die Bedingung, sodass **beide Zahlen entweder positiv oder negativ sind**.

# %%
a, b = -5, -10
if ____:
    print("Beide Zahlen sind entweder positiv oder negativ")

# %% [markdown]
# ## Aufgabe 11: Rabattprüfung

# %% [markdown]
# Ergänze die Bedingung, sodass eine Person nur dann **rabattberechtigt** ist, wenn sie entweder **Student oder über 65 Jahre alt** ist.

# %%
alter = 70
student = False
if ____:
    print("Rabatt gewährt")  # Erwartete Ausgabe: Rabatt gewährt

# %% [markdown]
# ## Aufgabe 12: Login-Prüfung

# %% [markdown]
# Ergänze die Bedingung, sodass ein **Login erfolgreich** ist, wenn der Benutzername und das Passwort korrekt sind.

# %%
benutzer = "user123"
passwort = "pass123"
if ____:
    print("Login erfolgreich")  # Erwartete Ausgabe: Login erfolgreich

# %% [markdown]
# ## Aufgabe 13: Gerade oder durch 5 teilbar

# %% [markdown]
# Ergänze die Bedingung, sodass überprüft wird, ob eine **Zahl entweder gerade oder durch 5 teilbar ist**.

# %%
num = 25
if ____:
    print("Die Zahl ist gerade oder durch 5 teilbar")  # Erwartete Ausgabe: Die Zahl ist gerade oder durch 5 teilbar

# %% [markdown]
# ## Aufgabe 14: Namensprüfung

# %% [markdown]
# Ergänze die Bedingung, sodass geprüft wird, ob ein Name entweder **'Alice' oder 'Bob'** ist.

# %%
name = "Alice"
if ____:
    print("Willkommen, Alice oder Bob!")  # Erwartete Ausgabe: Willkommen, Alice oder Bob!

# %% [markdown]
# ## Aufgabe 15: Liste prüfen

# %% [markdown]
# Ergänze die Bedingung, sodass geprüft wird, ob eine Liste **nicht leer** ist.

# %%
items = [1, 2, 3]
if ____:
    print("Die Liste ist nicht leer")  # Erwartete Ausgabe: Die Liste ist nicht leer

# %% [markdown]
# ## Aufgabe 16: Benutzerantwort validieren

# %% [markdown]
# Ergänze die Bedingung, sodass eine **Benutzerantwort als gültig erkannt** wird (nur 'ja' oder 'nein').

# %%
antwort = input("Möchtest du fortfahren? (ja/nein): ")
if ____:
    print("Gültige Antwort")  # Erwartete Ausgabe: Gültige Antwort

# %% [markdown]
# ## Aufgabe 17: Passwortstärke prüfen

# %% [markdown]
# Ergänze die Bedingung, sodass geprüft wird, ob das **eingegebene Passwort stark genug** ist (länger als `8` Zeichen).

# %%
passwort = input("Gib dein Passwort ein: ")
if ____:
    print("Passwort akzeptiert")  # Erwartete Ausgabe: Passwort akzeptiert

# %% [markdown]
# ## Aufgabe 18: Alterseingabe validieren

# %% [markdown]
# Ergänze die Bedingung, sodass geprüft wird, ob eine Zahl **eine gültige Alterseingabe** ist (`0-120`).

# %%
alter = int(input("Gib dein Alter ein: "))
if ____:
    print("Gültiges Alter")  # Erwartete Ausgabe: Gültiges Alter

# %% [markdown]
# ## Aufgabe 19: Zeichenprüfung

# %% [markdown]
# Ergänze die Bedingung, sodass geprüft wird, ob eine Zeichenkette **mindestens ein Zeichen enthält**.

# %%
text = input("Gib einen Text ein: ")
if ____:
    print("Der Text enthält Zeichen")  # Erwartete Ausgabe: Der Text enthält Zeichen

# %% [markdown]
# ## Aufgabe 20: Datum validieren

# %% [markdown]
# Ergänze die Bedingung, sodass ein Datum als **gültig** erkannt wird (`1-31` für den Tag und `1-12` für den Monat).

# %%
tag = 15
monat = 6
if ____:
    print("Gültiges Datum")  # Erwartete Ausgabe: Gültiges Datum
