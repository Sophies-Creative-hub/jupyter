# %% [markdown]
# ## Aufgabe 1: Gerade und größer als 10

# %% [markdown]
# Ergänze die Bedingung, sodass eine Zahl nur dann akzeptiert wird, wenn sie **gerade und größer als 10** ist.

# %%
num = 14
if ____:
    print("Die Zahl ist gerade und größer als 10")  # Erwartete Ausgabe: Die Zahl ist gerade und größer als 10

# %% [markdown]
# ## Aufgabe 2: Admin-Rolle und aktives Konto

# %% [markdown]
# Ergänze die Bedingung, sodass nur Benutzer mit **Admin-Rolle und aktivem Konto** Zugriff erhalten.

# %%
rolle = "Admin"
aktiv = True
if ____:
    print("Zugang gewährt")  # Erwartete Ausgabe: Zugang gewährt

# %% [markdown]
# ## Aufgabe 3: Erwachsene mit Mitgliedschaft

# %% [markdown]
# Ergänze die Bedingung, sodass nur Erwachsene (18+) mit einer Mitgliedschaft teilnehmen können.

# %%
alter = 20
mitglied = True
if ____:
    print("Teilnahme erlaubt")  # Erwartete Ausgabe: Teilnahme erlaubt

# %% [markdown]
# ## Aufgabe 4: Produktkauf

# %% [markdown]
# Ergänze die Bedingung, sodass ein Produkt nur gekauft werden kann, wenn der Kunde **genügend Guthaben und eine gültige Kreditkarte hat**.

# %%
guthaben = 50
kreditkarte = True
preis = 30
if ____:
    print("Kauf erfolgreich")  # Erwartete Ausgabe: Kauf erfolgreich

# %% [markdown]
# ## Aufgabe 5: Rabatt für Studenten oder Senioren

# %% [markdown]
# Ergänze die Bedingung, sodass eine Person Rabatt bekommt, wenn sie **Student oder über 65 Jahre alt ist**.

# %%
alter = 70
student = False
if ____:
    print("Rabatt gewährt")  # Erwartete Ausgabe: Rabatt gewährt

# %% [markdown]
# ## Aufgabe 6: Teilbarkeit durch 3 oder 5

# %% [markdown]
# Ergänze die Bedingung, sodass eine Zahl gültig ist, wenn sie entweder **durch 3 oder durch 5** teilbar ist.

# %%
zahl = 15
if ____:
    print("Die Zahl ist gültig")  # Erwartete Ausgabe: Die Zahl ist gültig

# %% [markdown]
# ## Aufgabe 7: Zugang für Admin oder Moderator

# %% [markdown]
# Ergänze die Bedingung, sodass ein Benutzer nur dann Zugang hat, wenn er **„Admin“ oder „Moderator“ ist**.

# %%
rolle = "Moderator"
if ____:
    print("Zugang erlaubt")  # Erwartete Ausgabe: Zugang erlaubt

# %% [markdown]
# ## Aufgabe 8: Eingabe Ja oder J

# %% [markdown]
# Ergänze die Bedingung, sodass eine Eingabe nur dann akzeptiert wird, wenn sie **„Ja“ oder „J“ enthält**.

# %%
antwort = "Ja"
if ____:
    print("Eingabe akzeptiert")  # Erwartete Ausgabe: Eingabe akzeptiert

# %% [markdown]
# ## Aufgabe 9: Premium- oder VIP-Kunde

# %% [markdown]
# Ergänze die Bedingung, sodass der Nutzer ein **Premium- oder VIP-Kunde ist und sein Konto aktiv ist**.

# %%
kunde = "VIP"
aktiv = True
if ____:
    print("Zugang zu Premium-Inhalten")  # Erwartete Ausgabe: Zugang zu Premium-Inhalten

# %% [markdown]
# ## Aufgabe 10: Gerade oder durch 5 teilbar

# %% [markdown]
# Ergänze die Bedingung, sodass eine **gerade Zahl oder eine durch 5 teilbare Zahl akzeptiert wird, aber nur wenn sie positiv ist**.

# %%
num = 20
if ____:
    print("Zahl akzeptiert")  # Erwartete Ausgabe: Zahl akzeptiert

# %% [markdown]
# ## Aufgabe 11: Bewerbung mit Erfahrung oder Zertifikat

# %% [markdown]
# Ergänze die Bedingung, sodass ein Bewerber **entweder über 3 Jahre Erfahrung oder eine Zertifizierung hat und mindestens 18 Jahre alt ist**.

# %%
erfahrung = 4
zertifizierung = False
alter = 22
if ____:
    print("Bewerbung akzeptiert")  # Erwartete Ausgabe: Bewerbung akzeptiert

# %% [markdown]
# ## Aufgabe 12: Nachricht senden

# %% [markdown]
# Ergänze die Bedingung, sodass eine Nachricht nur gesendet wird, wenn **das Konto aktiv ist und die Person nicht blockiert wurde**.

# %%
aktiv = True
blockiert = False
if ____:
    print("Nachricht gesendet")  # Erwartete Ausgabe: Nachricht gesendet

# %% [markdown]
# ## Aufgabe 13: Loginprüfung

# %% [markdown]
# Ergänze die Bedingung, sodass ein Login nur erlaubt ist, wenn das Konto **nicht gesperrt ist**.

# %%
gesperrt = False
if ____:
    print("Login erlaubt")  # Erwartete Ausgabe: Login erlaubt

# %% [markdown]
# ## Aufgabe 14: Liste nicht leer

# %% [markdown]
# Ergänze die Bedingung, sodass eine Liste nur dann verarbeitet wird, wenn sie **nicht leer** ist.

# %%
daten = [1, 2, 3]
if ____:
    print("Daten verarbeitet")  # Erwartete Ausgabe: Daten verarbeitet

# %% [markdown]
# ## Aufgabe 15: Bestellung erlauben

# %% [markdown]
# Ergänze die Bedingung, sodass eine Bestellung nur durchgeführt wird, wenn der Kunde **nicht auf der schwarzen Liste steht**.

# %%
blacklist = False
if ____:
    print("Bestellung durchgeführt")  # Erwartete Ausgabe: Bestellung durchgeführt

# %% [markdown]
# ## Aufgabe 16: E-Mail senden

# %% [markdown]
# Ergänze die Bedingung, sodass eine E-Mail nur versendet wird, wenn der Benutzer **nicht abgemeldet ist**.

# %%
abgemeldet = False
if ____:
    print("E-Mail gesendet")  # Erwartete Ausgabe: E-Mail gesendet

# %% [markdown]
# ## Aufgabe 17: Bewerber ohne Sperre

# %% [markdown]
# Ergänze die Bedingung, sodass nur Bewerber **mit Erfahrung oder Studium und ohne Sperrung** angenommen werden.

# %%
erfahrung = True
studium = False
gesperrt = False
if ____:
    print("Bewerbung erfolgreich")  # Erwartete Ausgabe: Bewerbung erfolgreich

# %% [markdown]
# ## Aufgabe 18: Reservierung

# %% [markdown]
# Ergänze die Bedingung, sodass eine Reservierung nur durchgeführt wird, wenn entweder **eine Kreditkarte oder PayPal verfügbar ist und das Konto aktiv ist**.

# %%
kreditkarte = True
paypal = False
konto_aktiv = True
if ____:
    print("Reservierung erfolgreich")  # Erwartete Ausgabe: Reservierung erfolgreich

# %% [markdown]
# ## Aufgabe 19: Zugriff für VIP oder Premium

# %% [markdown]
# Ergänze die Bedingung, sodass ein Benutzer nur dann Zugriff auf exklusive Inhalte erhält, wenn er **VIP oder Premium ist, aber nicht auf der Sperrliste steht**.

# %%
status = "VIP"
gesperrt = False
if ____:
    print("Zugriff gewährt")  # Erwartete Ausgabe: Zugriff gewährt

# %% [markdown]
# ## Aufgabe 20: Spielzugang

# %% [markdown]
# Ergänze die Bedingung, sodass ein Nutzer nur dann Zugriff auf ein Spiel bekommt, wenn er **18 Jahre oder älter ist und entweder eine Lizenz gekauft hat oder ein kostenloses Testkonto hat**.

# %%
alter = 19
lizenz = False
testkonto = True
if ____:
    print("Zugriff auf das Spiel")  # Erwartete Ausgabe: Zugriff auf das Spiel
