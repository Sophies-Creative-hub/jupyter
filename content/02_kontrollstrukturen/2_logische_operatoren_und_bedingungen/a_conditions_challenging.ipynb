# %% [markdown]
# ## Aufgabe 1: Primzahlprüfung

# %% [markdown]
# Ergänze die Bedingung, sodass eine Zahl nur akzeptiert wird, wenn sie **eine Primzahl zwischen 10 und 100** ist.

# %%
num = 17
if ____:
    print("Die Zahl ist eine Primzahl zwischen 10 und 100") # Erwartete Ausgabe: Die Zahl ist eine Primzahl zwischen 10 und 100

# %% [markdown]
# ## Aufgabe 2: Bewerberprüfung

# %% [markdown]
# Ergänze die Bedingung, sodass ein Bewerber nur akzeptiert wird, wenn er **mindestens 5 Jahre Erfahrung oder einen Doktortitel hat UND unter 50 Jahre alt ist**.

# %%
erfahrung = 6
titel = "Dr."
alter = 45
if ____:
    print("Bewerber akzeptiert") # Erwartete Ausgabe: Bewerber akzeptiert

# %% [markdown]
# ## Aufgabe 3: Rabattprüfung

# %% [markdown]
# Ergänze die Bedingung, sodass ein Rabatt nur dann gewährt wird, wenn der Kunde entweder **Mitglied ist oder über 70 Jahre alt ist, aber nicht gesperrt wurde**.

# %%
mitglied = False
alter = 72
gesperrt = False
if ____:
    print("Rabatt gewährt") # Erwartete Ausgabe: Rabatt gewährt

# %% [markdown]
# ## Aufgabe 4: Loginprüfung

# %% [markdown]
# Ergänze die Bedingung, sodass ein Nutzer sich nur anmelden kann, wenn **das Konto aktiv ist UND das Passwort korrekt ist ODER ein einmaliges Login-Ticket existiert**.

# %%
konto_aktiv = True
passwort_korrekt = False
login_ticket = True
if ____:
    print("Login erfolgreich") # Erwartete Ausgabe: Login erfolgreich

# %% [markdown]
# ## Aufgabe 5: Nachrichtenversand

# %% [markdown]
# Ergänze die Bedingung, sodass eine Nachricht nur gesendet wird, wenn der Empfänger **nicht blockiert ist und entweder online ist oder eine Benachrichtigung aktiviert hat**.

# %%
blockiert = False
online = False
benachrichtigung = True
if ____:
    print("Nachricht gesendet") # Erwartete Ausgabe: Nachricht gesendet

# %% [markdown]
# ## Aufgabe 6: Wahrheitsprüfung

# %% [markdown]
# Ergänze die Bedingung, sodass ein Wert nur dann verarbeitet wird, wenn er nicht `None` ist und seine Länge größer als 5 ist.

# %%
wert = "Python"
if ____:
    print("Wert verarbeitet") # Erwartete Ausgabe: Wert verarbeitet

# %% [markdown]
# ## Aufgabe 7: Dateilöschung

# %% [markdown]
# Ergänze die Bedingung, sodass eine Datei nur dann gelöscht wird, wenn sie **existiert und entweder leer oder älter als 30 Tage ist**.

# %%
existiert = True
leer = False
alter_tage = 45
if ____:
    print("Datei gelöscht") # Erwartete Ausgabe: Datei gelöscht

# %% [markdown]
# ## Aufgabe 8: Alle Zahlen gerade

# %% [markdown]
# Ergänze die Bedingung, sodass geprüft wird, ob **alle Werte in einer Liste gerade sind**.

# %%
zahlen = [2, 4, 6, 8]
if ____:
    print("Alle Zahlen sind gerade")  # Erwartete Ausgabe: Alle Zahlen sind gerade

# %% [markdown]
# ## Aufgabe 9: Teilbarkeit durch 3 prüfen

# %% [markdown]
# Ergänze die Bedingung, sodass geprüft wird, ob **mindestens eine Zahl in einer Liste durch 3 teilbar ist**.

# %%
zahlen = [5, 10, 15, 20]
if ____:
    print("Mindestens eine Zahl ist durch 3 teilbar")  # Erwartete Ausgabe: Mindestens eine Zahl ist durch 3 teilbar

# %% [markdown]
# ## Aufgabe 10: Spielzugang

# %% [markdown]
# Ergänze die Bedingung, sodass ein User nur spielen kann, wenn er **nicht gebannt ist und entweder genügend Spielzeit oder VIP-Status hat**.

# %%
gebannt = False
spielzeit = 2
vip = False
if ____:
    print("Spielzugriff erlaubt") # Erwartete Ausgabe: Spielzugriff erlaubt

# %% [markdown]
# ## Aufgabe 11: Bestellung erlauben

# %% [markdown]
# Ergänze die Bedingung, sodass eine Bestellung nur durchgeführt wird, wenn der Kunde **nicht auf der schwarzen Liste steht und entweder eine Kreditkarte oder genügend Guthaben hat**.

# %%
blacklist = False
kreditkarte = False
guthaben = 100
if ____:
    print("Bestellung durchgeführt") # Erwartete Ausgabe: Bestellung durchgeführt

# %% [markdown]
# ## Aufgabe 12: Ternärer Operator

# %% [markdown]
# Verwende einen **ternären Operator**, um eine Nachricht zurückzugeben, die sagt, ob eine Zahl positiv, negativ oder null ist.

# %%
zahl = -7
ergebnis = ____
print(ergebnis) # Erwartete Ausgabe: "Negativ"

# %% [markdown]
# ## Aufgabe 13: Zugriff auf Premium-Bereich

# %% [markdown]
# Ergänze die Bedingung, sodass nur Benutzer mit **einem Namen mit mindestens 5 Zeichen ODER einer Premium-Mitgliedschaft UND nicht gesperrt** Zugang erhalten.

# %%
name = "Anna"
premium = False
gesperrt = False
if ____:
    print("Zugang erlaubt") # Erwartete Ausgabe: Keine Ausgabe

# %% [markdown]
# ## Aufgabe 14: String-Validierung

# %% [markdown]
# Ergänze die Bedingung, sodass geprüft wird, ob ein Wort entweder mit `"A"` beginnt oder mit `"Z"` endet.

# %%
wort = "Apfel"
if ____:
    print("Gültiges Wort") # Erwartete Ausgabe: Gültiges Wort

# %% [markdown]
# ## Aufgabe 15: Benutzerrollen prüfen

# %% [markdown]
# Ergänze die Bedingung, sodass geprüft wird, ob ein Benutzer eine **von mehreren akzeptierten Rollen hat**.

# %%
rolle = "Moderator"
akzeptierte_rollen = {"Admin", "Moderator", "Support"}
if ____:
    print("Rolle akzeptiert") # Erwartete Ausgabe: Rolle akzeptiert

# %% [markdown]
# ## Aufgabe 16: Dictionary-Prüfung

# %% [markdown]
# Ergänze die Bedingung, sodass geprüft wird, ob ein **Schlüssel in einem Dictionary existiert und der zugehörige Wert größer als 10 ist**.

# %%
daten = {"score": 15}
if ____:
    print("Gültiger Score") # Erwartete Ausgabe: Gültiger Score

# %% [markdown]
# ## Aufgabe 17: E-Mail-Priorisierung

# %% [markdown]
# Ergänze die Bedingung, sodass geprüft wird, ob eine E-Mail entweder als **„wichtig“ markiert ist oder von einem VIP-Kontakt stammt**.

# %%
email = {"wichtig": False, "absender": "VIP"}
if ____:
    print("E-Mail hervorheben") # Erwartete Ausgabe: E-Mail hervorheben

# %% [markdown]
# ## Aufgabe 18: Perfekte Zahl

# %% [markdown]
# Ergänze die Bedingung, sodass eine Zahl als **perfekte Zahl** erkannt wird (`Summe der Teiler = Zahl selbst`).

# %%
zahl = 28
if ____:
    print("Perfekte Zahl") # Erwartete Ausgabe: Perfekte Zahl

# %% [markdown]
# ## Aufgabe 19: Potenzprüfung

# %% [markdown]
# Ergänze die Bedingung, sodass überprüft wird, ob eine Zahl entweder **eine Potenz von 2 oder eine Potenz von 3 ist**.

# %%
zahl = 9
if ____:
    print("Potenz von 2 oder 3") # Erwartete Ausgabe: Potenz von 2 oder 3

# %% [markdown]
# ## Aufgabe 20: Fibonacci-Zahl

# %% [markdown]
# Ergänze die Bedingung, sodass eine Zahl als **Fibonacci-Zahl** erkannt wird.

# %%
zahl = 21
if ____:
    print("Fibonacci-Zahl") # Erwartete Ausgabe: Fibonacci-Zahl
