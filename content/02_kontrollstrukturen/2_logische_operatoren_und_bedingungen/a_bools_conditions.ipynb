# %% [markdown]
# ## Aufgabe 1: Einführung in Booleans

# %% [markdown]
# Ergänze den Code, sodass `True` in der Variablen `wahrheit` gespeichert wird.

# %%
wahrheit = ____
print(wahrheit)  # Erwartete Ausgabe: True

# %% [markdown]
# ## Aufgabe 2: False-Wert speichern

# %% [markdown]
# Ergänze den Code, sodass `False` in der Variablen `falschheit` gespeichert wird.

# %%
falschheit = ____
print(falschheit)  # Erwartete Ausgabe: False

# %% [markdown]
# ## Aufgabe 3: Vergleichsoperatoren verwenden

# %% [markdown]
# Ergänze den Code, um den Wahrheitswert einer Vergleichsoperation zu speichern.

# %%
ist_gleich = (10 ____ 10)
print(ist_gleich)  # Erwartete Ausgabe: True

ist_ungleich = (10 ____ 5)
print(ist_ungleich)  # Erwartete Ausgabe: False

# %% [markdown]
# ## Aufgabe 4: Zahlenvergleiche

# %% [markdown]
# Ergänze den Code, um zu überprüfen, ob `5 kleiner als 10` ist.

# %%
print(5 ____ 10)  # Erwartete Ausgabe: True
print(10 ____ 5)  # Erwartete Ausgabe: False

# %% [markdown]
# ## Aufgabe 5: Größer oder gleich prüfen

# %% [markdown]
# Ergänze den Code, um zu überprüfen, ob `7 größer oder gleich 7` ist.

# %%
print(7 ____ 7)  # Erwartete Ausgabe: True
print(6 ____ 7)  # Erwartete Ausgabe: False

# %% [markdown]
# ## Aufgabe 6: Ungleichheitsprüfung

# %% [markdown]
# Ergänze den Code, um zu überprüfen, ob `100` **nicht gleich** `50` ist.

# %%
print(100 ____ 50)  # Erwartete Ausgabe: True
print(50 ____ 50)  # Erwartete Ausgabe: False

# %% [markdown]
# ## Aufgabe 7: if-Bedingungen

# %% [markdown]
# Ergänze die fehlenden Zeichen, sodass die Bedingung `if` korrekt funktioniert.

# %%
x = 10
if x ____ 5:
    print("1. x ist größer als 5")  # Erwartete Ausgabe: x ist größer als 5

x = 3
if x ____ 5:
    print("2. x ist größer als 5")  # Erwartete Ausgabe: Keine Ausgabe

# %% [markdown]
# ## Aufgabe 8: if-else

# %% [markdown]
# Ergänze den Code, sodass die `else`-Bedingung ausgeführt wird.

# %%
y = 3
if y > 5:
    print("y ist groß")
____:
    print("y ist klein")  # Erwartete Ausgabe: y ist klein

# %% [markdown]
# ## Aufgabe 9: if-elif-else

# %% [markdown]
# Ergänze den Code, sodass `elif` eine zusätzliche Bedingung überprüft.

# %%
z = 10
if z < 5:
    print("z ist klein")
____ z == 10:
    print("z ist genau 10")  # Erwartete Ausgabe: z ist genau 10
else:
    print("z ist größer als 10")

# %% [markdown]
# ## Aufgabe 10: Mehrere Bedingungen kombinieren

# %% [markdown]
# Ergänze den Code, sodass überprüft wird, ob `x` entweder **kleiner als 5 oder größer als 15** ist.

# %%
x = 20
if x ____ 5 ____ x ____ 15:
    print("1. x liegt außerhalb des Bereichs")  # Erwartete Ausgabe: 1. x liegt außerhalb des Bereichs

x = 10
if x ____ 5 ____ x ____ 15:
    print("2. x liegt außerhalb des Bereichs")  # Erwartete Ausgabe: Keine Ausgabe

# %% [markdown]
# ## Aufgabe 11: `and`-Operator

# %% [markdown]
# Ergänze den Code, um zwei Bedingungen mit `and` zu kombinieren.

# %%
a = 6
b = 12
print(a > 5 ____ b < 15)  # Erwartete Ausgabe: True
print(a > 10 ____ b < 15)  # Erwartete Ausgabe: False

# %% [markdown]
# ## Aufgabe 12: `or`-Operator

# %% [markdown]
# Ergänze den Code, um zwei Bedingungen mit `or` zu kombinieren.

# %%
a = 4
b = 20
print(a > 10 ____ b < 25)  # Erwartete Ausgabe: True
print(a > 10 ____ b > 25)  # Erwartete Ausgabe: False

# %% [markdown]
# ## Aufgabe 13: `not`-Operator

# %% [markdown]
# Ergänze den Code, um eine Bedingung mit `not` umzudrehen.

# %%
x = False
print(____ x)  # Erwartete Ausgabe: True

y = True
print(____ y)  # Erwartete Ausgabe: False

# %% [markdown]
# ## Aufgabe 14: Überprüfung auf `None`

# %% [markdown]
# Ergänze den Code, sodass überprüft wird, ob eine Variable **gesetzt** ist.

# %%
wert = None
if ____ :
    print("Wert ist nicht None")
else:
    print("Wert ist None")  # Erwartete Ausgabe: Wert ist None

# %% [markdown]
# ## Aufgabe 15: Boolean-Prüfung einer Variable

# %% [markdown]
# Ergänze den Code, um eine Variable als Boolean direkt zu prüfen.

# %%
text = ""
if ____ :
    print("Der Text ist nicht leer")
else:
    print("Der Text ist leer")  # Erwartete Ausgabe: Der Text ist leer

# %% [markdown]
# ## Aufgabe 16: Überprüfung einer leeren Liste

# %% [markdown]
# Ergänze den Code, um eine Liste auf **Leere** zu prüfen.

# %%
liste = []
if not ____:
    print("Die Liste ist leer")  # Erwartete Ausgabe: Die Liste ist leer

# %% [markdown]
# ## Aufgabe 17: Bereichsprüfung

# %% [markdown]
# Ergänze den Code, sodass nur Zahlen zwischen `10` und `20` akzeptiert werden.

# %%
zahl = 15
if 10 ____ zahl ____ 20:
    print("1. Zahl liegt im Bereich")  # Erwartete Ausgabe: 1. Zahl liegt im Bereich

zahl = 25
if 10 ____ zahl ____ 20:
    print("2. Zahl liegt im Bereich")  # Erwartete Ausgabe: Keine Ausgabe

# %% [markdown]
# ## Aufgabe 18: Altersüberprüfung

# %% [markdown]
# Ergänze den Code, sodass eine Altersüberprüfung funktioniert.

# %%
alter = 17
if alter ____ 18:
    print("Du bist volljährig")
else:
    print("Du bist noch minderjährig")  # Erwartete Ausgabe: Du bist noch minderjährig

# %% [markdown]
# ## Aufgabe 19: Prüfung auf gerade Zahlen

# %% [markdown]
# Ergänze den Code, um zu überprüfen, ob eine Zahl **gerade** ist.

# %%
zahl = 8
if zahl ____ 2 == 0:
    print("1. Die Zahl ist gerade")  # Erwartete Ausgabe: 1. Die Zahl ist gerade

zahl = 7
if zahl ____ 2 == 0:
    print("2. Die Zahl ist gerade")  # Erwartete Ausgabe: Keine Ausgabe

# %% [markdown]
# ## Aufgabe 20: Prüfung auf ungerade Zahlen

# %% [markdown]
# Ergänze den Code, um zu prüfen, ob eine Zahl **ungerade** ist.

# %%
zahl = 7
if zahl % 2 != 0:
    print("1. Die Zahl ist ungerade")  # Erwartete Ausgabe: 1. Die Zahl ist ungerade

zahl = 8
if zahl % 2 != 0:
    print("2. Die Zahl ist ungerade")  # Erwartete Ausgabe: Keine Ausgabe
# Out:
# 1. Die Zahl ist ungerade
