# %%
# Übung 1:

# 1.1 Erstelle ein leeres Dictionary mit dem Namen dog.

dog = {}

# 1.2 Füge dem dog-Dictionary folgende Schlüssel hinzu: name, color, breed, legs, age.

dog["Name"] = ""

# dog = {
#     "Name": "",
#     "Color": "",
#     "Breed": "",
#     "Legs": "",
#     "Age": ""
# }

print(dog)

# 1.3 Erstelle ein student-Dictionary und füge die folgenden Schlüssel hinzu: first_name, last_name, gender, age, marital_status, skills, country, city und address.

student_dictionary = {
    "first_name": "Bruce",
    "last_name": "Wayne",
    "gender": "male",
    "age": 30,
    "marital_status": "single",
    "skills": ["martial arts", "gadget master"],
    "country": "America",
    "city": "Gotham",
    "address": "Wayne Manor"
}

# 1.4 Bestimme die Länge des student-Dictionaries.

print(len(student_dictionary))

# 1.5 Gib den Wert von skills aus und überprüfe den Datentyp (er sollte eine Liste sein).

print(student_dictionary["skills"])
print(type(student_dictionary["skills"]))

# 1.6 Ändere den Wert von skills, indem du ein oder zwei zusätzliche Fähigkeiten hinzufügst.

# student_dictionary["skills"] = [student_dictionary["skills"], "Kämpfen", "Fliegen"]
student_dictionary["skills"].append("Verfassungsrecht")
student_dictionary["skills"].append("Fliegen")
print(student_dictionary["skills"])

# 1.7 Gib die Schlüssel (keys) des student-Dictionaries als Liste aus.

print(student_dictionary.keys())

# 1.8 Gib die Werte (values) des student-Dictionaries als Liste aus.

print(student_dictionary.values())

values_list = list(student_dictionary.values())
print(values_list)

# 1.9 Wandle das Dictionary mithilfe der items()-Methode in eine Liste von Tupeln um.

list_students =


items_als_dict_list = student_dictionary.items() # dict_items [("vorname", "Bruce")]  type: dict_list

items_als_copy_list = list(items_als_dict_list)  # [("vorname", "Bruce")]             type: list

erste_eintag_der_liste = items_als_copy_list[0]  # ("vorname", "Bruce")               type: tuple

print(erste_eintag_der_liste[0])                 # "vorname"                          type: String

# print(list(student_dictionary.items()))
# print(type(list(student_dictionary.items())[0]))
# print(type(list(student_dictionary.items())[0]))

# 1.10 Lösche einen der Einträge im student-Dictionary.

del student_dictionary["last_name"]
print(student_dictionary)

# 1.11 Lösche eines der beiden Dictionaries komplett.

del dog
# Out:
# {'Name': ''}
# 9
# ['martial arts', 'gadget master']
# <class 'list'>
# ['martial arts', 'gadget master', 'Verfassungsrecht', 'Fliegen']
# dict_keys(['first_name', 'last_name', 'gender', 'age', 'marital_status', 'skills', 'country', 'city', 'address'])
# dict_values(['Bruce', 'Wayne', 'male', 30, 'single', ['martial arts', 'gadget master', 'Verfassungsrecht', 'Fliegen'], 'America', 'Gotham', 'Wayne Manor'])
# ['Bruce', 'Wayne', 'male', 30, 'single', ['martial arts', 'gadget master', 'Verfassungsrecht', 'Fliegen'], 'America', 'Gotham', 'Wayne Manor']
# first_name
# {'first_name': 'Bruce', 'gender': 'male', 'age': 30, 'marital_status': 'single', 'skills': ['martial arts', 'gadget master', 'Verfassungsrecht', 'Fliegen'], 'country': 'America', 'city': 'Gotham', 'address': 'Wayne Manor'}

# %%
# 🚗 Übung 2: Speed-Ranking
# Ziel:
# Schreibe ein Python-Programm, das:

# Den Benutzer mehrfach nach einem Namen und einer Geschwindigkeit (in km/h) fragt.

# Alle Einträge speichert.

# Ausgibt, wer der schnellste war und mit welcher Geschwindigkeit.

# Anforderungen:
# Nach jedem Eintrag soll das Programm fragen, ob ein weiterer Eintrag gemacht werden soll (z.B. ja/nein).

# Nutze ein Dictionary, um die Daten zu speichern, z.B.:

# ```python
# daten = {"Anna": 120, "Ben": 140, ...}
# ```

# Beispiel Ablauf:

# Name eingeben: Anna
# Geschwindigkeit eingeben (km/h): 120
# Weitere Eingabe? (ja/nein): ja
# Name eingeben: Ben
# Geschwindigkeit eingeben (km/h): 140
# Weitere Eingabe? (ja/nein): nein

# Der Schnellste ist Ben mit 140 km/h!

# %%
# Übung 3:
# Schreibe ein Programm, das die Punktzahlen in Noten umwandelt.
# Am Ende deines Programms soll ein neues Dictionary namens schueler_noten entstehen,
# das die Namen der Schüler als Schlüssel und deren bewertete Noten als Werte enthält.

# Notenschlüssel
# 85-100 Punkte: Hervorragend
# 70-84: Erwartungen übertroffen
# 50-69: Akzeptabel
# <50: Nicht bestanden

# Vorgegebene Punktzahlen
schueler_punkte = {
    'Anna': 88,
    'Ben': 78,
    'Clara': 95,
    'David': 75,
    'Emma': 60
}

# %%
# Eine kollektion an ungeordneten veränderbaren Schlüssel paar Werten

bsp_dict = {
    "Name": "Max",
    "Alter": 30,
    "Beruf": "Softwareentwickler",
    "Hobbys": ["Lesen", "Programmieren", "Reisen"],
    "Volljährig": True,
    "Anmerkung": None,
    "Haustiere": [
        {
            "Name": "Bello",
            "Alter": 5
        },
        {
            "Name": "Miau",
            "Alter": 3
        }
    ]
}

print(bsp_dict)
print(len(bsp_dict))
print(bsp_dict["Anmerkung"])
print(bsp_dict["Hobbys"])

bsp_list = ["Haus", "Maus", "Laus"]

bsp_list.append("Raus")

bsp_dict["Hobbys"].append("Fotografie")

print(bsp_dict["Hobbys"].values())
# Out:
# {'Name': 'Max', 'Alter': 30, 'Beruf': 'Softwareentwickler', 'Hobbys': ['Lesen', 'Programmieren', 'Reisen'], 'Volljährig': True, 'Anmerkung': None}
# 6
# None
# ['Lesen', 'Programmieren', 'Reisen']
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-39852c8bbfea> in <cell line: 0>()
#      21 bsp_dict["Hobbys"].append("Fotografie")
#      22
# ---> 23 print(bsp_dict["Hobbys"].values())
#
# AttributeError: 'list' object has no attribute 'values'

# %%
my_list = [
    "Boot",
    "Auto",
    5,
    True,
    [
      ["Apfle", "Banane"],
      ["Hund", "Katze", "Katze", "Katze", "Katze", "Katze", "Katze", "Katze", "Katze", "Katze", "Katze", "Katze", "Katze"]
    ],
    {
        "Name": "Bello",
        "Alter": 5
    }
    ]

print(my_list[0])
print(my_list[1])
print(my_list[2])
print(my_list[3])
print(my_list[4][0][1])
print(my_list[5]["Name"])
# Out:
# Boot
# Auto
# 5
# True
# Banane
# Bello

# %%
# Suche nach hotels

deine_hotels = [
    {
     "Hotelname": "Hülton",
     "Stadt": "London",
     "Preis": 19,
     "Services": ["Wäsche", "Frühstück"]
     },
    {
     "Hotelname": "Morriot",
     "Stadt": "London",
     "Preis": 27,
     "Services": ["Wecker", "Frühstück"]
    },
    {
     "Hotelname": "Steves Garage",
     "Stadt": "London",
     "Preis": 5,
     "Services": ["Wäsche", "Frühstück"]
    }
]

deine_hotels[0]["Preis"] = 22
print(deine_hotels[0])
print("Hat das Hotel Services?")
# hat das erste Hotel Services
print("Services" in deine_hotels[0])
# hat das erste Hotel explizit den Service Wäsche
print("Wäsche" in deine_hotels[0]["Services"])
print("Wäsche" in deine_hotels[1]["Services"])
# Out:
# {'Hotelname': 'Hülton', 'Stadt': 'London', 'Preis': 22, 'Services': ['Wäsche', 'Frühstück']}
# Hat das Hotel Services?
# True
# True
# False

# %%
# datentyp list -> []
my_list = ["Apfel", "Banane", "Apfel", "Wassermelone"]
# sortiert -> ich kann über den index eindeutig den Platz des Elementes Identifizieren
#  --> my_list[0] ist immer "Apfel"
# es darf dublikate geben siehe Apfel
# die Liste kann verändert werden --> my_list[1] = "Brot"

# datentyp tuple -> ()
my_tuple = ("Apfel", "Banane", "Apfel", "Wassermelone")
# sortiert -> ich kann über den index eindeutig den Platz des Elementes Identifizieren
#  --> my_tuple[0] ist immer "Apfel"
# es darf dublikate geben siehe Apfel
# es ist unveränderbar!

# datentyp set -> {}
my_set = {"Apfel", "Banane", "Apfel", "Wassermelone"}
# unsortiert, wir können einträge NICHT über einen index finden
# es gibt keine dublikate!
# print(my_set) -> {'Banane', 'Wassermelone', 'Apfel'}
# es kann verändert werden
# Out:
# {'Banane', 'Wassermelone', 'Apfel'}

# %%
# Suche nach hotels

deine_hotels = [
    {
     "Hotelname": "Hülton",
     "Stadt": "London",
     "Preis": 19,
     "Services": ["Wäsche", "Frühstück"]
     },
    {
     "Hotelname": "Morriot",
     "Stadt": "London",
     "Preis": 27,
     "Services": ["Wecker", "Frühstück"]
    },
    {
     "Hotelname": "Steves Garage",
     "Stadt": "London",
     "Preis": 5,
     "Services": ["Wäsche", "Frühstück"]
    }
]


meine_hotels = deine_hotels

x = 5

print(f"1. x ist {x}")

z = x # -------> z = 5

print(f"2. x ist {x} und z ist {z}")

x = 2 # -------> z = 5 bleibt

print(f"3. x ist {x} und z ist {z}")

z = x

print(f"4. x ist {x} und z ist {z}")
# Out:
# 1. x ist 5
# 2. x ist 5 und z ist 5
# 3. x ist 2 und z ist 5
# 4. x ist 2 und z ist 2
# [{'Hotelname': 'Hülton', 'Stadt': 'London', 'Preis': 19, 'Services': ['Wäsche', 'Frühstück']}, {'Hotelname': 'Morriot', 'Stadt': 'London', 'Preis': 27, 'Services': ['Wecker', 'Frühstück']}, {'Hotelname': 'Steves Garage', 'Stadt': 'London', 'Preis': 5, 'Services': ['Wäsche', 'Frühstück']}]
