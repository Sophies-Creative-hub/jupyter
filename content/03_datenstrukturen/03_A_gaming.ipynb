# %% [markdown]
# # 🎮 Python-Übungen im Gaming-Style
# Alle Aufgaben basieren auf Kapitel 3 & 4 und fördern kreatives Denken.

# %% [markdown]
# ## Aufgabe 1: XP-Level-Up
# Berechne das Level eines Spielers mit 450 Erfahrungspunkten. Jedes Level benötigt 120 XP.
#
# *Implementiere den vollständigen Code in der folgenden Codezelle.*

# %%
# Dein Code hier

# %% [markdown]
# ## Aufgabe 2: Bosskampf – Schadensanzeige
# Ein Boss hat 1500 HP. Dein Spieler trifft mit 180, 220 und 165 Schaden. Berechne verbleibende HP.
#
# *Implementiere den vollständigen Code in der folgenden Codezelle.*

# %%
# Dein Code hier

# %% [markdown]
# ## Aufgabe 3: Mana-Verbrauch
# Du hast 80 Mana. Jeder Zauber kostet 12 Mana. Wie viele Zauber kannst du wirken, wie viel bleibt übrig?
#
# *Implementiere den vollständigen Code in der folgenden Codezelle.*

# %%
# Dein Code hier

# %% [markdown]
# ## Aufgabe 4: Highscore-Tabelle
# Speichere zwei Spielernamen und ihre Punktzahlen. Gib aus, wer führt oder ob es ein Unentschieden gibt.
#
# *Implementiere den vollständigen Code in der folgenden Codezelle.*

# %%
# Dein Code hier

# %% [markdown]
# ## Aufgabe 5: Item-Gewicht
# 3 Schwerter à 4.5 kg, 2 Schilde à 6 kg, 1 Trank à 1.2 kg. Berechne das Gesamtgewicht.
#
# *Implementiere den vollständigen Code in der folgenden Codezelle.*

# %%
# Dein Code hier

# %% [markdown]
# ## Aufgabe 6: Shop-Rabatt
# Ein Rüstungsset kostet 250 Gold. Es gibt 15 % Rabatt. Berechne den neuen Preis.
#
# *Implementiere den vollständigen Code in der folgenden Codezelle.*

# %%
# Dein Code hier

# %% [markdown]
# ## Aufgabe 7: Goldschatz in Truhen
# Du findest 7 Truhen mit je 134 Gold. Berechne den Gesamtwert.
#
# *Implementiere den vollständigen Code in der folgenden Codezelle.*

# %%
# Dein Code hier

# %% [markdown]
# ## Aufgabe 8: Spielcharakter erstellen
# Speichere Name, Klasse und Level deines Avatars. Gib ein Willkommensfenster mit diesen Infos aus.
#
# *Implementiere den vollständigen Code in der folgenden Codezelle.*

# %%
# Dein Code hier

# %% [markdown]
# ## Aufgabe 9: Bonuspunkte für Kombos
# Ein Angriff bringt 100 Punkte. Jede 3. Aktion gibt +50 Bonus. Berechne Punkte nach 9 Aktionen.
#
# *Implementiere den vollständigen Code in der folgenden Codezelle.*

# %%
# Dein Code hier

# %% [markdown]
# ## Aufgabe 10: Bossvergleich
# Boss 1: 1800 HP, Boss 2: 2450 HP. Berechne die Differenz und wie viel Prozent Boss 2 stärker ist.
#
# *Implementiere den vollständigen Code in der folgenden Codezelle.*

# %%
# Dein Code hier

# %% [markdown]
# ## Aufgabe 11: Teleportkosten
# Teleport kostet 3.5 Mana/km. Berechne die Kosten für 12.8 km.
#
# *Implementiere den vollständigen Code in der folgenden Codezelle.*

# %%
# Dein Code hier

# %% [markdown]
# ## Aufgabe 12: Code-Kombination
# Erzeuge den Zeichenstring '479' aus drei Ziffern 4, 7, 9.
#
# *Implementiere den vollständigen Code in der folgenden Codezelle.*

# %%
# Dein Code hier

# %% [markdown]
# ## Aufgabe 13: Shopkauf mit Restgold
# Du hast 1000 Gold. Du kaufst drei Items für 399, 199 und 149 Gold. Berechne dein Restgold.
#
# *Implementiere den vollständigen Code in der folgenden Codezelle.*

# %%
# Dein Code hier

# %% [markdown]
# ## Aufgabe 14: Namensschild in Pixelwelt
# Ein Name soll 20 Zeichen lang sein, rechts mit * auffüllen (z. B. 'Max***************').
#
# *Implementiere den vollständigen Code in der folgenden Codezelle.*

# %%
# Dein Code hier

# %% [markdown]
# ## Aufgabe 15: Score-Prozente
# Du hast 7560 von 9000 Punkten. Berechne den Prozentwert und gib an, ob es ein Highscore ist (ab 85 %).
#
# *Implementiere den vollständigen Code in der folgenden Codezelle.*

# %%
# Dein Code hier
