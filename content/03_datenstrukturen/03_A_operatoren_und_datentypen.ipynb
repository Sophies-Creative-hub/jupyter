# %% [markdown]
# # Interaktive Übungen zu Kapitel 4: Operatoren und Datentypen

# %% [markdown]
# ## Übung 1: Teile und herrsche

# %%
aepfel = 10
freunde = 3

# Ergänze den Code
pro_person = ____________________
rest = ____________________

print("Jeder bekommt:", pro_person, "Äpfel")
print("Übrig bleiben:", rest)

# %% [markdown]
# ## Übung 2: Pow!

# %%
basis = 3
exponent = 4

# TODO: Ergänze die Berechnung der Potenz
ergebnis = ____________________
print("Ergebnis:", ergebnis)

# %% [markdown]
# ## Übung 3: Durchschnitt bitte!

# %%
note1 = 1.3
note2 = 2.0
note3 = 1.7

# TODO: Berechne den gerundeten Schnitt
schnitt = ____________________
print("Durchschnittsnote:", round(schnitt, 2))

# %% [markdown]
# ## Übung 4: Wiederholung hilft

# %%
zeichen = "="

# TODO: Wiederhole das Zeichen 40-mal
linie = ____________________
print(linie)

# %% [markdown]
# ## Übung 5: Begrüßung erweitern

# %%
vorname = "Jonas"
nachname = "Müller"

# TODO: Verknüpfe Strings mit Leerzeichen
gruss = ____________________
print(gruss)

# %% [markdown]
# ## Übung 6: Rabattaktion

# %%
preis = 80

# TODO: Preis um 25 % senken
____________________

print("Neuer Preis:", preis)

# %% [markdown]
# ## Übung 7: Klick mich!

# %%
klicks = 0

# TODO: Erhöhe die Klicks um 3
____________________
____________________
____________________

print("Klicks insgesamt:", klicks)

# %% [markdown]
# ## Übung 8: Falsche Typen

# %%
alter = 30
name = "Sina"

# TODO: Verknüpfe Name und Alter richtig
ausgabe = ____________________
print(ausgabe)

# %% [markdown]
# ## Übung 9: Kontostand updaten

# %%
kontostand = 300

# TODO: Verwende Kurzformen für die Änderungen
____________________
____________________

print("Aktueller Kontostand:", kontostand)

# %% [markdown]
# ## Übung 10: Summe addieren

# %%
gesamt = 0
betrag1 = 4.99
betrag2 = 1.50

# TODO: Ergänze zwei Kurzzuweisungen
____________________
____________________

print("Gesamt:", gesamt)

# %% [markdown]
# ## Übung 11: Strings vervielfachen

# %%
produkt = "Apfel\n"

# TODO: Gib den Produktnamen 5-mal untereinander aus
liste = ____________________
print(liste)

# %% [markdown]
# ## Übung 12: Welcher Typ bist du?

# %%
x = 3.14
y = "Python"
z = True

# TODO: Gib die Typen aus
print(type(______))
print(type(______))
print(type(______))

# %% [markdown]
# ## Übung 13: Falscher Code!

# %%
preis = 3.99
text = "Preis: " + preis + " Euro"
print(text)

# %% [markdown]
# ## Übung 14: Monatswechsel

# %%
monat = 5

# TODO: Ergänze die Kurzform
____________________

print("Neuer Monat:", monat)

# %% [markdown]
# ## Übung 15: Deine Signatur

# %%
# TODO: Aufgabe: Erstelle einen Block mit deinem Namen, eingerahmt von Sternen.
